# %%
# %load_ext dotenv
# %dotenv ../src/.env

import os
os.getenv('PRICE_DATA')
# Out:
# '../data/prices/'

# %% [markdown]
# # What are we doing?
#
# ## Objectives
#
# * Build a data pipeline that downloads price data from the internet, stores it locally, transforms it into return data, and stores the feature set.
#     - Getting the data.
#     - Schemas and index in dask.
#
# * Explore the parquet format.
#     - Reading and writing parquet files.
#     - Read datasets that are stored in distributed files.
#     - Discuss dask vs pandas as a small example of big vs small data.
#
# * Discuss the use of environment variables for settings.
# * Discuss how to use Jupyter notebooks and source code concurrently.
# * Logging and using a standard logger.
#
# ## About the Data
#
# + We will download the prices for a list of stocks.
# + The source is Yahoo Finance and we will use the API provided by the library yfinance.
#
#
# ## Medallion Architecture
#
# + The architecture that we are thinking about is called Medallion by [DataBricks](https://www.databricks.com/glossary/medallion-architecture). It is an ELT type of thinking, although our data is well-structured.
#
# ![Medallion Architecture (DataBicks)](./img/medallion-architecture.png)
#
# + In our case, we would like to optimize the number of times that we download data from the internet.
# + Ultimately, we will build a pipeline manager class that will help us control the process of obtaining and transforming our data.
#
# ![](./img/target_pipeline_manager.png)

# %% [markdown]
# # Download Data from Yahoo Finance
#
# Yahoo Finance provides information about public stocks in different markets. The library yfinance gives us access to a fair bit of the data in Yahoo Finance.
#
# These steps are based on the instructions in:
#
# + [yfinance documentation](https://pypi.org/project/yfinance/)
# + [Tutorial in geeksforgeeks.org](https://www.geeksforgeeks.org/get-financial-data-from-yahoo-finance-with-python/)

# %% [markdown]
# + If required, install: `python -m pip install yfinance`.
# + To download the price history of a stock, first use the following setup:

# %%
# loading libraries
import pandas as pd
import yfinance as yf

# os library to get access to environment files
# already called  above
# import os
import sys

import warnings
# to silence warnings produced by yfinance, not necessary
warnings.filterwarnings("ignore", category=FutureWarning, module="yfinance")

# system path is the path the computer will follow to execute commands
# e.g. cmd "import os" the path already contains a directory where the library os is stored /
# I want that path to also contain all of the code that I will be running and I want it to make it /
# available to Jupyter Notebooks and the path is in the /src directory
# so the path.append command will add the /src directory to Jupyter Notebook's kernel
sys.path.append("../src")

# %% [markdown]
# A few things to notice in the code chunk above:
#
# + Libraries are ordered from high-level to low-level libraries from the package manager (pip in this case, but could be conda, poetry, etc.)
# + The command `sys.path.append("../src/)` will add the `../src/` directory to the path in the Notebook's kernel. This way, we can use our modules as part of the notebook.
# + Local modules are imported at the end.
# + The function `get_logger()` is called with `__name__` as recommended by the documentation.

# %% [markdown]
# Now, to download the historical price data for a stock, we could use:

# %%
# to look at what a stock looks like

# Ticker class will generate a ticker object;
# we have instantiated a class and now we have a specific version of that class called AAPL
# 'class' is an abstract concept of something that will have certain behaviour
# a class encapsulates attributes, variables and functions
# 'object' is the specific concrete implementation of that class
stock = yf.Ticker("AAPL")

# now stock has some behaviour, I can get from it some stock history
# only one way of unequivocally stating dates and that is YYYY-MM-DD
px_dt = stock.history(start = "2013-12-01", end = "2024-02-01")
# what happened is I have created an object
# the variable "AAPL" that I have encapsulated in my object, in my concrete version of the class,
# is the ticker name, the start date and the end date  

px_dt
# px_dt.columns
# px_dt.shape
# px_dt.head
# px_dt.index
# Out:
#                                  Open        High         Low       Close  \
# Date
# 2013-12-02 00:00:00-05:00   17.448939   17.646880   17.224417   17.237238
# 2013-12-03 00:00:00-05:00   17.458327   17.710993   17.438939   17.709116
# 2013-12-04 00:00:00-05:00   17.683478   17.798866   17.537132   17.667843
# 2013-12-05 00:00:00-05:00   17.907056   17.984919   17.711928   17.758520
# 2013-12-06 00:00:00-05:00   17.692545   17.722565   17.498044   17.512114
# ...                               ...         ...         ...         ...
# 2024-01-25 00:00:00-05:00  194.971211  196.019876  192.863900  193.922546
# 2024-01-26 00:00:00-05:00  194.022423  194.511788  191.695390  192.174774
# 2024-01-29 00:00:00-05:00  191.765299  191.955059  189.338403  191.485657
# 2024-01-30 00:00:00-05:00  190.696667  191.555572  187.231088  187.800354
# 2024-01-31 00:00:00-05:00  186.801628  186.861565  184.115069  184.164993
#
#                               Volume  Dividends  Stock Splits
# Date
# 2013-12-02 00:00:00-05:00  472544800        0.0           0.0
# 2013-12-03 00:00:00-05:00  450968000        0.0           0.0
# 2013-12-04 00:00:00-05:00  377809600        0.0           0.0
# 2013-12-05 00:00:00-05:00  447580000        0.0           0.0
# 2013-12-06 00:00:00-05:00  344352400        0.0           0.0
# ...                              ...        ...           ...
# 2024-01-25 00:00:00-05:00   54822100        0.0           0.0
# 2024-01-26 00:00:00-05:00   44594000        0.0           0.0
# 2024-01-29 00:00:00-05:00   47145600        0.0           0.0
# 2024-01-30 00:00:00-05:00   55859400        0.0           0.0
# 2024-01-31 00:00:00-05:00   55467800        0.0           0.0
#
# [2558 rows x 7 columns]

# %% [markdown]
# ## Parametrize the download
#
# + in the case with "AAPL", we worked with a single stock but we want work with big datasets so we need to parametrize with 500 stocks at a time
# + Generally, we will look to separate every parameter and setting from functions.
# + If we had a few stocks, we could cycle through them. We need a place to store the list of tickers (a db or file, for example).
# + Store a csv file with a few stock tickers. The location of the file is a setting, the contents of this file are parameters.
# + Use **environment variables** to pass parameters.

# %%
# notice using capital letters for environment variables
# using capital letters for TICKERS is a convention
# I can choose not to follow this convention but will make life difficult
ticker_file = os.getenv("TICKERS")

# reading the first 20 rows of the S&P500_wiki CSV into Pandas
tickers = pd.read_csv(ticker_file).head(20)
tickers
# Out:
#    ticker                         Security             GICS Sector  \
# 0     MMM                               3M             Industrials
# 1     AOS                      A. O. Smith             Industrials
# 2     ABT                           Abbott             Health Care
# 3    ABBV                           AbbVie             Health Care
# 4     ACN                        Accenture  Information Technology
# 5    ADBE                       Adobe Inc.  Information Technology
# 6     AMD           Advanced Micro Devices  Information Technology
# 7     AES                  AES Corporation               Utilities
# 8     AFL                            Aflac              Financials
# 9       A             Agilent Technologies             Health Care
# 10    APD       Air Products and Chemicals               Materials
# 11   ABNB                           Airbnb  Consumer Discretionary
# 12   AKAM                           Akamai  Information Technology
# 13    ALB            Albemarle Corporation               Materials
# 14    ARE  Alexandria Real Estate Equities             Real Estate
# 15   ALGN                 Align Technology             Health Care
# 16   ALLE                         Allegion             Industrials
# 17    LNT                   Alliant Energy               Utilities
# 18    ALL                         Allstate              Financials
# 19  GOOGL          Alphabet Inc. (Class A)  Communication Services
#
#                                GICS Sub-Industry      Headquarters Location  \
# 0                       Industrial Conglomerates      Saint Paul, Minnesota
# 1                              Building Products       Milwaukee, Wisconsin
# 2                          Health Care Equipment    North Chicago, Illinois
# 3                                  Biotechnology    North Chicago, Illinois
# 4                 IT Consulting & Other Services            Dublin, Ireland
# 5                           Application Software       San Jose, California
# 6                                 Semiconductors    Santa Clara, California
# 7   Independent Power Producers & Energy Traders        Arlington, Virginia
# 8                        Life & Health Insurance          Columbus, Georgia
# 9                 Life Sciences Tools & Services    Santa Clara, California
# 10                              Industrial Gases    Allentown, Pennsylvania
# 11                Hotels, Resorts & Cruise Lines  San Francisco, California
# 12            Internet Services & Infrastructure   Cambridge, Massachusetts
# 13                           Specialty Chemicals  Charlotte, North Carolina
# 14                                  Office REITs       Pasadena, California
# 15                          Health Care Supplies             Tempe, Arizona
# 16                             Building Products            Dublin, Ireland
# 17                            Electric Utilities         Madison, Wisconsin
# 18                 Property & Casualty Insurance       Northbrook, Illinois
# 19                  Interactive Media & Services  Mountain View, California
#
#     Date added      CIK      Founded
# 0        20883    66740         1902
# 1        42942    91142         1916
# 2        20883     1800         1888
# 3        41274  1551152  2013 (1888)
# 4        40730  1467373         1989
# 5        35555   796343         1982
# 6        42814     2488         1969
# 7        36070   874761         1981
# 8        36308     4977         1955
# 9        36682  1090872         1999
# 10       31167     2969         1940
# 11       45187  1559720         2008
# 12       39275  1086222         1998
# 13       42552   915913         1994
# 14       42814  1035443         1994
# 15       42905  1097149         1997
# 16       41610  1579241         1908
# 17       42552   352541         1917
# 18       34893   899051         1931
# 19       41732  1652044         1998

# %% [markdown]
# Collecting padas data frames
#
# + From the [documentation](https://pandas.pydata.org/docs/user_guide/merging.html):
#
# > [`concat()`](https://pandas.pydata.org/docs/reference/api/pandas.concat.html#pandas.concat) makes a full copy of the data, and iteratively reusing `concat()` can create unnecessary copies. Collect all DataFrame or Series objects in a list before using `concat()`.
#
# + We can string operation togethers using dot operations. Enclose the line in parenthesis and add linebreaks for readability.

# %%
# DON'T RUN
for k, row in tickers.iterrows():
    print(f'This is the {k}th row.')
    print(f'The row is {row}')

# %%
# List to hold final results
px_list = list()

for k, row in tickers.iterrows():  # Produces an iterator that returns index and row

    print(f"The ticker is {row['ticker']}\n\n")

    stock = yf.Ticker(row['ticker'])
    print(f'Processing {row["ticker"]}')
    
    # round parenthises are to put one command across multiple lines
    px = (stock
          # first operation
          .history(start = pd.to_datetime("2013-12-01"), 
                   end = pd.to_datetime("2024-02-01"))

          # had datetime in indices, reset index to get date as a column, date is now out of the index
          .reset_index()

          # assign 'ticker' name to dataframe, we now have a new variable called 'ticker' at the very end
          # we need this because we are goind to download 500 tickers
          # and we need to add this labelling mechanism
          .assign(ticker = row['ticker']))    # Add ticker
    
    # If we have a known condition, say price data contains a dataframe that does not have rows,
    # we ask for a certain stock and that stock returns no prices, we need our code to be reliable.
    # Here we create a test for shape[0], if the first element of shape which is the number of rows is equal to zero
    # then we need to alert the user, I don't want it to fail silently.
    # It will go to the next iteration of "for", it won't wait to go to the last line, skip to the next iteration
    # and continue to the top of the for loop, it won't execute "px_list.append(px)"
    if px.shape[0] == 0:
      print(f'No data for {row["ticker"]}')  # Validate: do not fail silently.
      continue
    # taking list created at top and appending my dataframe
    px_list.append(px)
    print(px.head(5))
# Out:
# The ticker is MMM
#
#
# Processing MMM
#                        Date       Open       High        Low      Close  \
# 0 2013-12-02 00:00:00-05:00  93.398053  93.632134  90.362102  90.567810
# 1 2013-12-03 00:00:00-05:00  89.418679  90.362094  88.773187  89.801720
# 2 2013-12-04 00:00:00-05:00  89.340638  90.503946  89.014345  89.702400
# 3 2013-12-05 00:00:00-05:00  89.659853  90.546521  89.532172  89.964867
# 4 2013-12-06 00:00:00-05:00  90.929582  91.362276  90.688405  91.227501
#
#     Volume  Dividends  Stock Splits ticker
# 0  6897900        0.0           0.0    MMM
# 1  7864500        0.0           0.0    MMM
# 2  3450700        0.0           0.0    MMM
# 3  2842700        0.0           0.0    MMM
# 4  2886100        0.0           0.0    MMM
# The ticker is AOS
#
#
# Processing AOS
#                        Date       Open       High        Low      Close  \
# 0 2013-12-02 00:00:00-05:00  23.161834  23.264453  22.918116  23.020735
# 1 2013-12-03 00:00:00-05:00  22.892464  23.042115  22.610263  22.759914
# 2 2013-12-04 00:00:00-05:00  22.708601  22.764186  22.345160  22.605982
# 3 2013-12-05 00:00:00-05:00  22.563231  22.635918  22.366546  22.456337
# 4 2013-12-06 00:00:00-05:00  22.601709  22.943770  22.601709  22.691500
#
#     Volume  Dividends  Stock Splits ticker
# 0   852400        0.0           0.0    AOS
# 1   885000        0.0           0.0    AOS
# 2  1029400        0.0           0.0    AOS
# 3  1130400        0.0           0.0    AOS
# 4  1054600        0.0           0.0    AOS
# The ticker is ABT
#
#
# Processing ABT
#                        Date       Open       High        Low      Close  \
# 0 2013-12-02 00:00:00-05:00  31.377562  31.434999  31.205245  31.295506
# 1 2013-12-03 00:00:00-05:00  31.139586  31.164201  30.573410  30.852394
# 2 2013-12-04 00:00:00-05:00  30.647257  31.057528  30.425713  30.655464
# 3 2013-12-05 00:00:00-05:00  30.598025  30.622640  30.269807  30.294422
# 4 2013-12-06 00:00:00-05:00  30.581624  30.803171  30.499568  30.794964
#
#     Volume  Dividends  Stock Splits ticker
# 0  5641200        0.0           0.0    ABT
# 1  7798700        0.0           0.0    ABT
# 2  5092700        0.0           0.0    ABT
# 3  5289800        0.0           0.0    ABT
# 4  4055000        0.0           0.0    ABT
# The ticker is ABBV
#
#
# Processing ABBV
#                        Date       Open       High        Low      Close  \
# 0 2013-12-02 00:00:00-05:00  31.886703  32.011645  31.577633  31.820942
# 1 2013-12-03 00:00:00-05:00  32.307550  33.050628  32.202335  32.859928
# 2 2013-12-04 00:00:00-05:00  32.715267  33.070368  32.419350  32.662659
# 3 2013-12-05 00:00:00-05:00  32.498254  32.925691  32.254946  32.721836
# 4 2013-12-06 00:00:00-05:00  32.991458  33.866058  32.912547  33.767418
#
#     Volume  Dividends  Stock Splits ticker
# 0  4321900        0.0           0.0   ABBV
# 1  9480100        0.0           0.0   ABBV
# 2  5309200        0.0           0.0   ABBV
# 3  5449100        0.0           0.0   ABBV
# 4  7285800        0.0           0.0   ABBV
# The ticker is ACN
#
#
# Processing ACN
#                        Date       Open       High        Low      Close  \
# 0 2013-12-02 00:00:00-05:00  64.775554  64.959624  63.712977  63.863579
# 1 2013-12-03 00:00:00-05:00  63.863581  64.624954  63.612575  64.499451
# 2 2013-12-04 00:00:00-05:00  63.169147  63.880322  62.867943  63.646053
# 3 2013-12-05 00:00:00-05:00  63.704629  63.830132  63.277921  63.411793
# 4 2013-12-06 00:00:00-05:00  63.562381  63.771550  62.893036  63.194241
#
#     Volume  Dividends  Stock Splits ticker
# 0  2489300        0.0           0.0    ACN
# 1  2138700        0.0           0.0    ACN
# 2  3550500        0.0           0.0    ACN
# 3  2197300        0.0           0.0    ACN
# 4  3259400        0.0           0.0    ACN
# The ticker is ADBE
#
#
# Processing ADBE
#                        Date       Open       High        Low      Close  \
# 0 2013-12-02 00:00:00-05:00  56.740002  57.029999  56.610001  56.759998
# 1 2013-12-03 00:00:00-05:00  56.630001  57.060001  56.389999  56.400002
# 2 2013-12-04 00:00:00-05:00  56.189999  56.430000  55.419998  56.049999
# 3 2013-12-05 00:00:00-05:00  55.630001  55.750000  54.470001  55.040001
# 4 2013-12-06 00:00:00-05:00  55.990002  56.099998  55.549999  55.599998
#
#     Volume  Dividends  Stock Splits ticker
# 0  1950800        0.0           0.0   ADBE
# 1  4129500        0.0           0.0   ADBE
# 2  3663500        0.0           0.0   ADBE
# 3  7792700        0.0           0.0   ADBE
# 4  3334300        0.0           0.0   ADBE
# The ticker is AMD
#
#
# Processing AMD
#                        Date  Open  High   Low  Close    Volume  Dividends  \
# 0 2013-12-02 00:00:00-05:00  3.65  3.70  3.56   3.66  24119700        0.0
# 1 2013-12-03 00:00:00-05:00  3.64  3.71  3.58   3.62  23323200        0.0
# 2 2013-12-04 00:00:00-05:00  3.57  3.63  3.48   3.57  21609700        0.0
# 3 2013-12-05 00:00:00-05:00  3.56  3.65  3.55   3.64  14465700        0.0
# 4 2013-12-06 00:00:00-05:00  3.67  3.70  3.63   3.66  15825300        0.0
#
#    Stock Splits ticker
# 0           0.0    AMD
# 1           0.0    AMD
# 2           0.0    AMD
# 3           0.0    AMD
# 4           0.0    AMD
# The ticker is AES
#
#
# Processing AES
#                        Date       Open       High        Low      Close  \
# 0 2013-12-02 00:00:00-05:00  10.463870  10.557234  10.377689  10.392053
# 1 2013-12-03 00:00:00-05:00  10.348961  10.693687  10.305871  10.686505
# 2 2013-12-04 00:00:00-05:00  10.650596  11.160503  10.578778  10.995322
# 3 2013-12-05 00:00:00-05:00  10.959414  10.980959  10.542870  10.585960
# 4 2013-12-06 00:00:00-05:00  10.686506  10.873233  10.614688  10.787051
#
#      Volume  Dividends  Stock Splits ticker
# 0   3855900        0.0           0.0    AES
# 1   7908600        0.0           0.0    AES
# 2  13164800        0.0           0.0    AES
# 3  11045800        0.0           0.0    AES
# 4   7457300        0.0           0.0    AES
# The ticker is AFL
#
#
# Processing AFL
#                        Date       Open       High        Low      Close  \
# 0 2013-12-02 00:00:00-05:00  25.892606  26.236022  25.798949  25.853582
# 1 2013-12-03 00:00:00-05:00  25.763826  25.876997  25.416510  25.576511
# 2 2013-12-04 00:00:00-05:00  25.568711  25.810663  25.451640  25.642859
# 3 2013-12-05 00:00:00-05:00  25.541388  25.892607  25.502364  25.638948
# 4 2013-12-06 00:00:00-05:00  25.919925  26.040903  25.798951  26.005779
#
#     Volume  Dividends  Stock Splits ticker
# 0  3772800        0.0           0.0    AFL
# 1  4596000        0.0           0.0    AFL
# 2  3349200        0.0           0.0    AFL
# 3  3877800        0.0           0.0    AFL
# 4  2920200        0.0           0.0    AFL
# The ticker is A
#
#
# Processing A
#                        Date       Open       High        Low      Close  \
# 0 2013-12-02 00:00:00-05:00  35.052676  35.183785  34.816674  34.882229
# 1 2013-12-03 00:00:00-05:00  34.692114  34.856006  34.456113  34.698669
# 2 2013-12-04 00:00:00-05:00  34.639674  35.288678  34.561009  35.124786
# 3 2013-12-05 00:00:00-05:00  34.974012  35.269013  34.823234  35.072346
# 4 2013-12-06 00:00:00-05:00  35.242803  36.009803  35.242803  35.944248
#
#     Volume  Dividends  Stock Splits ticker
# 0  2039962        0.0           0.0      A
# 1  3462706        0.0           0.0      A
# 2  3377288        0.0           0.0      A
# 3  2530939        0.0           0.0      A
# 4  4268513        0.0           0.0      A
# The ticker is APD
#
#
# Processing APD
#                        Date       Open       High        Low      Close  \
# 0 2013-12-02 00:00:00-05:00  78.852608  79.019072  77.803173  77.940681
# 1 2013-12-03 00:00:00-05:00  77.803155  77.803155  76.941888  77.557076
# 2 2013-12-04 00:00:00-05:00  77.441294  78.020297  77.043231  77.766983
# 3 2013-12-05 00:00:00-05:00  77.441286  77.694600  76.847814  77.086647
# 4 2013-12-06 00:00:00-05:00  78.027501  79.286831  77.766952  79.257881
#
#     Volume  Dividends  Stock Splits ticker
# 0  1199586        0.0           0.0    APD
# 1  1071271        0.0           0.0    APD
# 2   784374        0.0           0.0    APD
# 3   728702        0.0           0.0    APD
# 4   823938        0.0           0.0    APD
# The ticker is ABNB
#
#
# Processing ABNB
#                        Date        Open        High         Low       Close  \
# 0 2020-12-10 00:00:00-05:00  146.000000  165.000000  141.250000  144.710007
# 1 2020-12-11 00:00:00-05:00  146.550003  151.500000  135.100006  139.250000
# 2 2020-12-14 00:00:00-05:00  135.000000  135.300003  125.160004  130.000000
# 3 2020-12-15 00:00:00-05:00  126.690002  127.599998  121.500000  124.800003
# 4 2020-12-16 00:00:00-05:00  125.830002  142.000000  124.910004  137.990005
#
#      Volume  Dividends  Stock Splits ticker
# 0  70447500        0.0           0.0   ABNB
# 1  26980800        0.0           0.0   ABNB
# 2  16966100        0.0           0.0   ABNB
# 3  10914400        0.0           0.0   ABNB
# 4  20409600        0.0           0.0   ABNB
# The ticker is AKAM
#
#
# Processing AKAM
#                        Date       Open       High        Low      Close  \
# 0 2013-12-02 00:00:00-05:00  44.709999  44.709999  44.000000  44.110001
# 1 2013-12-03 00:00:00-05:00  43.919998  45.750000  43.869999  45.650002
# 2 2013-12-04 00:00:00-05:00  45.330002  46.549999  45.200001  45.860001
# 3 2013-12-05 00:00:00-05:00  45.910000  45.910000  44.759998  45.119999
# 4 2013-12-06 00:00:00-05:00  45.680000  45.740002  44.549999  44.950001
#
#     Volume  Dividends  Stock Splits ticker
# 0  2241700        0.0           0.0   AKAM
# 1  3123100        0.0           0.0   AKAM
# 2  3379900        0.0           0.0   AKAM
# 3  2563700        0.0           0.0   AKAM
# 4  2184100        0.0           0.0   AKAM
# The ticker is ALB
#
#
# Processing ALB
#                        Date       Open       High        Low      Close  \
# 0 2013-12-02 00:00:00-05:00  59.581966  60.412497  59.270516  59.599266
# 1 2013-12-03 00:00:00-05:00  59.374345  59.763661  58.595727  59.054249
# 2 2013-12-04 00:00:00-05:00  58.855267  59.426260  58.232367  58.760101
# 3 2013-12-05 00:00:00-05:00  58.621689  59.452219  58.318892  59.088863
# 4 2013-12-06 00:00:00-05:00  59.633894  60.282747  59.556028  60.144321
#
#    Volume  Dividends  Stock Splits ticker
# 0  643500        0.0           0.0    ALB
# 1  503300        0.0           0.0    ALB
# 2  407200        0.0           0.0    ALB
# 3  532700        0.0           0.0    ALB
# 4  349000        0.0           0.0    ALB
# The ticker is ARE
#
#
# Processing ARE
#                        Date       Open       High        Low      Close  \
# 0 2013-12-02 00:00:00-05:00  45.666716  46.057092  45.052237  45.652260
# 1 2013-12-03 00:00:00-05:00  45.493216  46.339028  45.370318  45.688404
# 2 2013-12-04 00:00:00-05:00  47.546299  47.929450  44.878736  45.052235
# 3 2013-12-05 00:00:00-05:00  44.922105  45.464293  44.726917  45.290794
# 4 2013-12-06 00:00:00-05:00  45.630555  45.984786  45.384763  45.753452
#
#    Volume  Dividends  Stock Splits ticker
# 0  341100        0.0           0.0    ARE
# 1  550300        0.0           0.0    ARE
# 2  563100        0.0           0.0    ARE
# 3  782800        0.0           0.0    ARE
# 4  554600        0.0           0.0    ARE
# The ticker is ALGN
#
#
# Processing ALGN
#                        Date       Open       High        Low      Close  \
# 0 2013-12-02 00:00:00-05:00  54.799999  55.500000  54.049999  55.110001
# 1 2013-12-03 00:00:00-05:00  54.889999  55.389999  54.639999  55.169998
# 2 2013-12-04 00:00:00-05:00  54.750000  55.250000  53.939999  54.650002
# 3 2013-12-05 00:00:00-05:00  54.540001  54.570000  53.830002  54.529999
# 4 2013-12-06 00:00:00-05:00  54.910000  55.790001  54.160000  55.459999
#
#    Volume  Dividends  Stock Splits ticker
# 0  547400        0.0           0.0   ALGN
# 1  660200        0.0           0.0   ALGN
# 2  558700        0.0           0.0   ALGN
# 3  520900        0.0           0.0   ALGN
# 4  453300        0.0           0.0   ALGN
# The ticker is ALLE
#
#
# Processing ALLE
#                        Date       Open       High        Low      Close  \
# 0 2013-12-02 00:00:00-05:00  39.003168  39.537330  37.590796  39.057487
# 1 2013-12-03 00:00:00-05:00  38.749675  40.605675  38.659140  38.840214
# 2 2013-12-04 00:00:00-05:00  38.414682  38.577648  37.708498  37.871464
# 3 2013-12-05 00:00:00-05:00  38.278879  38.278879  36.785027  37.165279
# 4 2013-12-06 00:00:00-05:00  36.893668  37.174332  36.794077  36.848400
#
#     Volume  Dividends  Stock Splits ticker
# 0  5130700        0.0           0.0   ALLE
# 1  3239300        0.0           0.0   ALLE
# 2  2777700        0.0           0.0   ALLE
# 3  3380500        0.0           0.0   ALLE
# 4  4662300        0.0           0.0   ALLE
# The ticker is LNT
#
#
# Processing LNT
#                        Date       Open       High        Low      Close  \
# 0 2013-12-02 00:00:00-05:00  18.580569  18.792939  18.404195  18.627363
# 1 2013-12-03 00:00:00-05:00  18.598566  18.753345  18.501381  18.652559
# 2 2013-12-04 00:00:00-05:00  18.558968  18.807332  18.515773  18.720943
# 3 2013-12-05 00:00:00-05:00  18.717350  18.717350  18.569771  18.652559
# 4 2013-12-06 00:00:00-05:00  18.720947  18.976511  18.670554  18.915319
#
#     Volume  Dividends  Stock Splits ticker
# 0  1192200        0.0           0.0    LNT
# 1   926200        0.0           0.0    LNT
# 2   909200        0.0           0.0    LNT
# 3   582200        0.0           0.0    LNT
# 4   491400        0.0           0.0    LNT
# The ticker is ALL
#
#
# Processing ALL
#                        Date       Open       High        Low      Close  \
# 0 2013-12-02 00:00:00-05:00  43.420925  43.476921  43.052952  43.124947
# 1 2013-12-03 00:00:00-05:00  42.924966  43.124952  42.596990  42.804974
# 2 2013-12-04 00:00:00-05:00  42.628998  43.052967  42.421011  42.852982
# 3 2013-12-05 00:00:00-05:00  42.764975  42.964960  42.532990  42.716980
# 4 2013-12-06 00:00:00-05:00  43.180957  43.564930  43.156960  43.452938
#
#     Volume  Dividends  Stock Splits ticker
# 0  1793300        0.0           0.0    ALL
# 1  2549200        0.0           0.0    ALL
# 2  2502100        0.0           0.0    ALL
# 3  2607900        0.0           0.0    ALL
# 4  2106100        0.0           0.0    ALL
# The ticker is GOOGL
#
#
# Processing GOOGL
#                        Date       Open       High        Low      Close  \
# 0 2013-12-02 00:00:00-05:00  26.614365  26.685434  26.295296  26.388388
# 1 2013-12-03 00:00:00-05:00  26.300051  26.612614  26.251753  26.357859
# 2 2013-12-04 00:00:00-05:00  26.310560  26.626125  26.276276  26.480982
# 3 2013-12-05 00:00:00-05:00  26.456455  26.518019  26.303555  26.459961
# 4 2013-12-06 00:00:00-05:00  26.771523  26.776777  26.528528  26.773523
#
#      Volume  Dividends  Stock Splits ticker
# 0  54873072        0.0           0.0  GOOGL
# 1  66976956        0.0           0.0  GOOGL
# 2  47616336        0.0           0.0  GOOGL
# 3  45302652        0.0           0.0  GOOGL
# 4  57094848        0.0           0.0  GOOGL

# %%
# concatonate one on top of the other
# concatenate is just another way of saying "to combine" or "to join together"
# like a layer cake, going to build layer by layer
# every layer with have the same schema (Date, Open, High, Low, Close, ...)
px_dt = pd.concat(px_list, axis = 0)
# axis = 0 vs axis = 1; there are two ways of putting together your dataframes,
# you can put them one on top of the other or you can put them side by side
# axis = 0 puts one on top of the other, in Pandas, axis = 0 means by rows

# create a dataframe that contains all of our price information
# that we can uniquely identify all of the different tickers
px_dt

# SUMMARY
# 1. we build the solution for a single stock, we understood how to get the data for a single stock
# 2. we got a list of stocks that we want to run the solution for
# 3. we iterate the individualized solution over the list of stocks
# 4. we collected all the different datasets into a single large dataset
# This pattern of using a blank list and then using concatonate at the end
# is the pattern for joining multiple datasets at the same time.
# When you get a ton of CSV, you need to put them together, create a list, append to the list, 
# and finally concatonate with the append function

print(f'Downloaded, final shape {px.shape}.')
# Out:
# Downloaded, final shape (2558, 9).

# %% [markdown]
# ## Reliability
#
# + Keppelman (2017) defines *reliability* as:
#
#     - A system should continue to work correctly.
#     - To work correctly means performing the correct function at the desired level of performance, even in the face of adversity such as hardware or software faults, and even human error.
#
# + *Faults* are things that can go wrong.
# + Sytems that can cope with (certain types of) faults are called *fault-tolerant* or *resilient*.
# + A fault is different than a failure.
#
#     - A *fault* occurs when a component of the system deviates from spec.
#     - A *failure*  is when the system stops providing the required service to the user.
#
# + In our simple example, we handle the fault that occurs when one ticker is not found and log it using *warning*.

# %% [markdown]
# # Storing Data in CSV

# %% [markdown]
# + We have some data. How do we store it?
# + We can compare two options, CSV and Parqruet, by measuring their performance:
#
#     - Time to save.
#     - Space required.

# %%
# fuction that returns the sizes of all the elements in a certain directory, in the repo

def get_dir_size(path='.'):
    '''Returns the total size of files contained in path.'''
    total = 0

    # Using scandir, get every single file you find in a path.
    # Using a recursive pattern to traverse all the directory and all of the files
    # to get thier sizes and add them up.
    # We are trying to measue how much time and space each one of my file types will cost
    with os.scandir(path) as it:
        # for every entry in the path... 
        for entry in it:
            # if it is a file, get it's size and add it to total
            if entry.is_file():
                total += entry.stat().st_size
            elif entry.is_dir():
                total += get_dir_size(entry.path)
    return total

# %%
import time

# %%
# To measure time
# if my directory does not exist, I will get an error
# trying to write to a none exisiting directory
# exist_ok, if it exists nothing will happen, else it will create it

# TEMP is an environment varible used by Windows, changed the name to TEMP_Data
temp = os.getenv("TEMP_DATA")

# IMPORTANT
# If the directory does not exist, I will get an error when I try to write into a none existing directory.
# 'exist_ok=True' - if True, nothing will happend, if False, it will create the directory.
os.makedirs(temp, exist_ok=True)

# creating a function that will join two paths, 'temp' and the price we got from file
stock_path = os.path.join(temp, "stock_px.csv")

# %%
# I want to first write my file into CSV then into Parquet.

# I want to measure time. 
# Time snapshot.
start = time.time()

# 
px_dt.to_csv(stock_path, index = False)

# Time snapshot.
end = time.time()

# 'end - start' will output the time the operation took
print(f'Writing to dt ({px_dt.shape})csv took {end - start} seconds.')
# Get data size of file
print(f'Csv file size { os.path.getsize(stock_path)*1e-6 } MB')
# Out:
# Writing to dt ((49391, 9))csv took 1.4060029983520508 seconds.
# Csv file size 5.904595 MB

# %% [markdown]
# ## Save Data to Parquet
#
# ### Dask
#
# We can work with with large data sets and parquet files. In fact, recent versions of pandas support pyarrow data types and future versions will require a pyarrow backend. The pyarrow library is an interface between Python and the Appache Arrow project. The [parquet data format](https://parquet.apache.org/) and [Arrow](https://arrow.apache.org/docs/python/parquet.html) are projects of the Apache Foundation.
#
# However, Dask is much more than an interface to Arrow: Dask provides parallel and distributed computing on pandas-like dataframes. It is also relatively easy to use, bridging a gap between pandas and Spark.

# %%
import dask
dask.config.set({'dataframe.query-planning': True})
import dask.dataframe as dd

# %%
# Dask is a library that extends pandas. It gives us parallel computaiton and access to the Parquet format.
# If you have a problem that is too big to handle in memory for Panadas, first try Dask and
# if much bigger, use Spark.
# Dask is an intermediate solution before you break out big data tools and have clustering.
# Dask will allow you to work on bigger dataframes because it parallelizes a fair bit of it's computations.
# pd to parquet will force you to use a single partition, Dask will allow you to partition it in mulple ways.
# Parquet are immutable, we need something to we can change
# create a name space, 
# create a directory perstock and a file per year

px_dd = dd.from_pandas(px_dt, npartitions = len(tickers))

# Run Parquet file format, first run 'path.join' to joining 'temp' with a directory name 'stock_px.parquet' 
parquet_path = os.path.join(temp, "stock_px.parquet")

# start a counter, stop the counter then make space
start = time.time()
px_dd.to_parquet(parquet_path, engine = "pyarrow")
end = time.time()

# difference is less than half, Parquet twice as fast to save as CSV
# less than half the time, less than half the space
print(f'Writing dd ({px_dt.shape}) to parquet took {end - start} seconds.')
print(f'Parquet file size { get_dir_size(parquet_path)*1e-6 } MB')
# Out:
# Writing dd ((49391, 9)) to parquet took 0.1735854148864746 seconds.
# Parquet file size 2.241513 MB

# %% [markdown]
# ### Parquet files and Dask Dataframes
#
# + Parquet files are immutable: once written, they cannot be modified.
# + Dask DataFrames are a useful implementation to manipulate data stored in parquets.
# + Parquet and Dask are not the same: parquet is a file format that can be accessed by many applications and programming languages (Python, R, PowerBI, etc.), while Dask is a package in Python to work with large datasets using distributed computation.
# + **Dask is not for everything** (see [Dask DataFrames Best Practices](https://docs.dask.org/en/stable/dataframe-best-practices.html)).
#
#     - Consider cases suchas small to larrge joins, where the small dataframe fits in memory, but the large one does not.
#     - If possible, use pandas: reduce, then use pandas.
#     - Pandas performance tips apply to Dask.
#     - Use the index: it is beneficial to have a well-defined index in Dask DataFrames, as it may speed up searching (filtering) the data. A one-dimensional index is allowed.
#     - Avoid (or minimize) full-data shuffling: indexing is an expensive operations.
#     - Some joins are more expensive than others.
#
#         * Not expensive:
#
#             - Join a Dask DataFrame with a pandas DataFrame.
#             - Join a Dask DataFrame with another Dask DataFrame of a single partition.
#             - Join Dask DataFrames along their indexes.
#
#         * Expensive:
#
#             - Join Dask DataFrames along columns that are not their index.

# %% [markdown]
# # How do we store prices?
#
# + We can store our data as a single blob. This can be difficult to maintain, especially because parquet files are immutable.
# + Strategy: organize data files by ticker and date. Update only latest month.

# %%
# Parquet files are binary, the way to open them is by using a Python Library and importing them.
# Python is not the only software, you can point your PowerBI instance to the directory and it will
# read Parquet and display all your price information with the ticker and you can do charts.
# You can point R to the directory and it will display your information. 

# With this function, I want to store prices in such a way so I can maintain them over the long term. 
# Remember: Parquet are immutable, once we write them, we can not append things to them.
# We need a strategy, that strategy relates to "Namespaces".
# I am going to use names of my files and folder structure to retain this information.  
# I am going to create a directory per stock and a Parquet file per year, 
# in this way I am only going to need to download the older years once, and 
# I can then rewrite the recent year every single time that I want to update my task.
# When I switch over to a new year, then that year will become historical.

PRICE_DATA = os.getenv("PRICE_DATA")

# loading ticker data, first iterating by date
for ticker in px_dt.ticker.unique():
    # take ticker by ticker and I'm going to subset my dataframe
    ticker_dt = px_dt[px_dt.ticker == ticker]
    # assigning a year
    ticker_dt = ticker_dt.assign(year = ticker_dt.Date.dt.year)
    # loading ticker data, second iterating by year
    for yr in ticker_dt.year.unique():
        yr_dt = ticker_dt[ticker_dt.year == yr]
        yr_path = os.path.join(PRICE_DATA, ticker, f"{ticker}_{yr}.parquet")
        
        # saving file data same as before
        # will create the directory if it doesn't already exist
        # These paths are in compliance with Linux, Windows and MacOS.
        # Using 'os.path.dirname', Python will take care of me irrespective of the OS I'm using.
        os.makedirs(os.path.dirname(yr_path), exist_ok=True)
        # writing directly to Parquet
        yr_dt.to_parquet(yr_path, engine = "pyarrow")

# SUMMARY
# What I end up with is a 'prices' directory and for every stock I get a different Parquet file.
# Given order to chaos. Started with a large blob of data, I cut it up, putting it into the right places.
# If this data is in an assured log storage, I can retain it.
# I am making my code Generalizable, Modularizable, and more Fault Tolerant.

# %%
# Pandas can work both ways
# px_dt.Date or px_dt['Date']

# a single column is called a 'series' in Pandas, 'Date' is an accessor
px_dt['Date']

# I can do accessors as in px_dt['Date'].dt.year, px_dt['Date'].dt.month, or px_dt['Date'].dt.day
# preferred way, both lines are same as above
# they add a 'year' column to the ind of dataframe
px_dt['year'] = px_dt['Date'].dt.year
px_dt = px_dt.assign(year = px_dt.Date.dt.year)

# %%
px_dt
# Out:
#                           Date        Open        High         Low  \
# 0    2013-12-02 00:00:00-05:00   93.398053   93.632134   90.362102
# 1    2013-12-03 00:00:00-05:00   89.418679   90.362094   88.773187
# 2    2013-12-04 00:00:00-05:00   89.340638   90.503946   89.014345
# 3    2013-12-05 00:00:00-05:00   89.659853   90.546521   89.532172
# 4    2013-12-06 00:00:00-05:00   90.929582   91.362276   90.688405
# ...                        ...         ...         ...         ...
# 2553 2024-01-25 00:00:00-05:00  150.070007  153.050003  149.539993
# 2554 2024-01-26 00:00:00-05:00  151.100006  152.539993  151.009995
# 2555 2024-01-29 00:00:00-05:00  152.059998  153.779999  151.429993
# 2556 2024-01-30 00:00:00-05:00  152.800003  153.619995  151.190002
# 2557 2024-01-31 00:00:00-05:00  143.619995  144.000000  139.869995
#
#            Close    Volume  Dividends  Stock Splits ticker  year
# 0      90.567810   6897900        0.0           0.0    MMM  2013
# 1      89.801720   7864500        0.0           0.0    MMM  2013
# 2      89.702400   3450700        0.0           0.0    MMM  2013
# 3      89.964867   2842700        0.0           0.0    MMM  2013
# 4      91.227501   2886100        0.0           0.0    MMM  2013
# ...          ...       ...        ...           ...    ...   ...
# 2553  151.869995  29149100        0.0           0.0  GOOGL  2024
# 2554  152.190002  26115500        0.0           0.0  GOOGL  2024
# 2555  153.509995  27784300        0.0           0.0  GOOGL  2024
# 2556  151.460007  36331800        0.0           0.0  GOOGL  2024
# 2557  140.100006  71910000        0.0           0.0  GOOGL  2024
#
# [49391 rows x 10 columns]

# %% [markdown]
# Why would we want to store data this way?
#
# + Easier to maintain. We do not update old data, only recent data.
# + We can also access all files as follows.

# %% [markdown]
# # Load, Transform and Save

# %% [markdown]
# ## Load
#
# + Parquet files can be read individually or as a collection.
# + `dd.read_parquet()` can take a list (collection) of files as input.
# + Use `glob` to get the collection of files.

# %%
# This is demonstrating how I am going to read the data I have featurizaed.
from glob import glob

# This is giving me a path with wildcards. Looking for all files with this structure.
# From the /data/prices directory, it will grab all files ending in .parquet.
# os.path.join(PRICE_DATA, "*/*.parquet")
parquet_files = glob(os.path.join(PRICE_DATA, "*/*.parquet"))

# parquet_files = glob(PRICE_DATA+"/**/*.parquet/*.parquet")
# 'dd' stands for Dask Dataframe
# Upon execution, Dask does nothing. It is a big data library. Big data libraries have lazy execution.
# Meaning no command will execute until ultimitly necessary. Reason being, we want to verify our code
# will run without errors and leave as much of the execution until the very end because once run,
# we might need to wait a few hours until it completes. This way of processing is called 'Lazy Execution'
dd_px = dd.read_parquet(parquet_files)
# dd_px = dd.read_parquet(parquet_files).set_index("ticker")

# %%
# To trigger the execution of the code I must run 'compute'.
# This will transform my Dask dataframe and compartmentalize it into a Pandas dataframe.
# Doing it for a single ticker item:  dd_px[dd_px.ticker == "ABBV"].compute()  
dd_px.compute()

# SUMMARY
# By passing the 'compute' command the parquet files and everything has been compiled into
# a single dataframe. Nothing needs to be done by hand, the dataframe has already joined.
# It has already been converted and put into Pandas.
# I have gone from a list of 20 files into a single dataframe in a single prompt.
# The power of Parquet, it allows me to break apart a very large datasets into individual components
# that can be managed individually and then when I need to read them I simply point to all of them
# at the same time and bring them back.
# Out:
#                           Date       Open       High        Low      Close  \
# 0    2013-12-02 00:00:00-05:00  35.052676  35.183785  34.816674  34.882229
# 1    2013-12-03 00:00:00-05:00  34.692114  34.856006  34.456113  34.698669
# 2    2013-12-04 00:00:00-05:00  34.639674  35.288678  34.561009  35.124786
# 3    2013-12-05 00:00:00-05:00  34.974012  35.269013  34.823234  35.072346
# 4    2013-12-06 00:00:00-05:00  35.242803  36.009803  35.242803  35.944248
# ...                        ...        ...        ...        ...        ...
# 2553 2024-01-25 00:00:00-05:00  92.247775  94.706929  92.080554  94.411835
# 2554 2024-01-26 00:00:00-05:00  94.647914  95.316805  94.224940  94.421669
# 2555 2024-01-29 00:00:00-05:00  94.431509  95.306967  93.880661  94.805298
# 2556 2024-01-30 00:00:00-05:00  94.598729  94.933178  93.231440  94.185593
# 2557 2024-01-31 00:00:00-05:00  94.372490  94.372490  92.621573  92.808464
#
#        Volume  Dividends  Stock Splits ticker  year
# 0     2039962        0.0           0.0      A  2013
# 1     3462706        0.0           0.0      A  2013
# 2     3377288        0.0           0.0      A  2013
# 3     2530939        0.0           0.0      A  2013
# 4     4268513        0.0           0.0      A  2013
# ...       ...        ...           ...    ...   ...
# 2553  6122900        0.0           0.0    MMM  2024
# 2554  3720200        0.0           0.0    MMM  2024
# 2555  3800000        0.0           0.0    MMM  2024
# 2556  3200500        0.0           0.0    MMM  2024
# 2557  6906800        0.0           0.0    MMM  2024
#
# [49391 rows x 10 columns]

# %% [markdown]
# ## Transform
#
# + This transformation step will create a *Features* data set. In our case, features will be stock returns (we obtained prices).
# + Dask dataframes work like pandas dataframes: in particular, we can perform groupby and apply operations.
# + Notice the use of [an anonymous (lambda) function](https://realpython.com/python-lambda/) in the apply statement.

# %%
# This is a map reduce operation.
# Calculate returns: take price series, group it by ticker, take a lagged price series, then calculate ratio.
# The closing price of today vs the previous closing price. 

import numpy as np

# concentrate on the grouby, lambda, most difficult part of the assignment
dd_rets = (dd_px.groupby('ticker', group_keys=False).apply(
    lambda x: x.assign(Close_lag_1 = x['Close'].shift(1))
).assign(
    returns = lambda x: x['Close']/x['Close_lag_1'] - 1
).assign(
    positive_return = lambda x: (x['returns'] > 0)*1
))
# Out:
# C:\Users\bash\AppData\Local\Temp\ipykernel_23436\1277655216.py:4: UserWarning: `meta` is not specified, inferred from partial data. Please provide `meta` if the result is unexpected.
#   Before: .apply(func)
#   After:  .apply(func, meta={'x': 'f8', 'y': 'f8'}) for dataframe result
#   or:     .apply(func, meta=('x', 'f8'))            for series result
#   dd_rets = (dd_px.groupby('ticker', group_keys=False).apply(

# %%
type(dd_rets)
# Out:
# dask_expr._collection.DataFrame

# %%
dd_rets.head(5)
# Out:
# c:\Users\bash\Documents\GitHub\production\env\Lib\site-packages\dask\dataframe\core.py:8391: UserWarning: Insufficient elements for `head`. 5 elements requested, only 0 elements available. Try passing larger `npartitions` to `head`.
#   warnings.warn(
# Empty DataFrame
# Columns: [Date, Open, High, Low, Close, Volume, Dividends, Stock Splits, ticker, year, Close_lag_1, returns, positive_return]
# Index: []

# %% [markdown]
# ## Lazy Exection
#
# What does `dd_rets` contain?

# %%
dd_rets
# Out:
# <dask_expr.expr.DataFrame: expr=Assign(frame=Assign(frame=Assign(frame=Assign(frame=Assign(frame=Assign(frame=GroupByApply(frame=ReadParquet(9c4803f), observed=False, group_keys=False, func=<function <lambda> at 0x000001FD3423D940>, meta=_NoDefault.no_default, args=(), kwargs={})))))))>

# %% [markdown]
# + Dask is a lazy execution framework: commands will not execute until they are required.
# + To trigger an execution in dask use `.compute()`.

# %%
dd_rets.compute()
# Out:
#                           Date        Open        High         Low  \
# 2537 2024-01-02 00:00:00-05:00  153.434029  158.624444  153.305270
# 2538 2024-01-03 00:00:00-05:00  159.070181  160.219206  158.327279
# 2539 2024-01-04 00:00:00-05:00  158.792836  160.754093  157.921159
# 2540 2024-01-05 00:00:00-05:00  159.803183  161.487091  159.089996
# 2541 2024-01-08 00:00:00-05:00  160.645139  161.229567  158.267858
# ...                        ...         ...         ...         ...
# 772  2016-12-23 00:00:00-05:00   29.584957   29.601774   29.408378
# 773  2016-12-27 00:00:00-05:00   29.496680   29.727909   29.442023
# 774  2016-12-28 00:00:00-05:00   29.521911   29.551340   29.303290
# 775  2016-12-29 00:00:00-05:00   29.370555   29.484067   29.345330
# 776  2016-12-30 00:00:00-05:00   29.437812   29.488263   29.189766
#
#            Close   Volume  Dividends  Stock Splits ticker  year  Close_lag_1  \
# 2537  158.307480  8059900        0.0           0.0   ABBV  2024          NaN
# 2538  158.941422  5301400        0.0           0.0   ABBV  2024   158.307480
# 2539  159.931961  8332200        0.0           0.0   ABBV  2024   158.941422
# 2540  160.605515  5607600        0.0           0.0   ABBV  2024   159.931961
# 2541  159.902237  6001600        0.0           0.0   ABBV  2024   160.605515
# ...          ...      ...        ...           ...    ...   ...          ...
# 772    29.492464  2147000        0.0           0.0    AFL  2016    29.589172
# 773    29.597580  1766600        0.0           0.0    AFL  2016    29.492464
# 774    29.345335  3138600        0.0           0.0    AFL  2016    29.597580
# 775    29.357943  2776600        0.0           0.0    AFL  2016    29.345335
# 776    29.261236  2387800        0.0           0.0    AFL  2016    29.357943
#
#        returns  positive_return
# 2537       NaN                0
# 2538  0.004004                1
# 2539  0.006232                1
# 2540  0.004212                1
# 2541 -0.004379                0
# ...        ...              ...
# 772  -0.003268                0
# 773   0.003564                1
# 774  -0.008522                0
# 775   0.000430                1
# 776  -0.003294                0
#
# [49391 rows x 13 columns]

# %% [markdown]
# ## Save
#
# + Apply transformations to calculate daily returns
# + Store the enriched data, the silver dataset, in a new directory.
# + Should we keep the same namespace? All columns?

# %%
features_path = os.getenv("FEATURES_DATA")
dd_rets.to_parquet(features_path, engine = "pyarrow")

# %% [markdown]
# # A few notes
#
# # Jupyter?
#
# + We have drafted our code in a Jupyter Notebook.
# + Finalized code should be written in Python modules.
#
# ## Object oriented programming?
#
# + We can use classes to keep parameters and functions together.
# + We *could* use Object Oriented Programming, but parallelization of data manipulation and modelling tasks benefits from *Functional Programming*.
# + An Idea:
#
#     - [Data Oriented Programming](https://blog.klipse.tech/dop/2022/06/22/principles-of-dop.html).
#     - Use the class to bundle together parameters and functions.
#     - Use stateless operations and treat all data objects as immutable (we do not modify them, we overwrite them).
#     - Take advantage of [`@staticmethod`](https://realpython.com/instance-class-and-static-methods-demystified/).
#
# The code is in `./src/`.

# %% [markdown]
# Our original design was:
#
# ![](./img/target_pipeline_manager.png)
#
# Our resulting interface is:

# %%
# don't run it all, delete your prices folder
# we are runnign two processedures at the same time
# dataManager class is 
# download all of our data
# there is a subprocess to process each ticker
# we are adding logs for each procedure
# everytime something is run, we log it
# DataManager class 
# static method have nothign to do with class, they take data into and output standard stuff
# it will change with the funciton
from data_manager import DataManager
dm = DataManager()

# %%
dm.download_all()
# Out:
# 2024-03-03 20:36:46,714, data_manager.py, 50, INFO, Getting price data for all tickers.
# 2024-03-03 20:36:46,714, data_manager.py, 50, INFO, Getting price data for all tickers.
# 2024-03-03 20:36:46,717, data_manager.py, 59, INFO, Getting tickers from ../data/tickers/sp500_wiki.csv
# 2024-03-03 20:36:46,717, data_manager.py, 59, INFO, Getting tickers from ../data/tickers/sp500_wiki.csv
# 2024-03-03 20:36:46,768, data_manager.py, 65, INFO, Processing all tickers
# 2024-03-03 20:36:46,768, data_manager.py, 65, INFO, Processing all tickers
# 2024-03-03 20:36:46,781, data_manager.py, 80, INFO, Processing ticker MMM
# 2024-03-03 20:36:46,781, data_manager.py, 80, INFO, Processing ticker MMM
# 2024-03-03 20:36:46,783, data_manager.py, 115, INFO, Getting stock price data for MMM from 2000-01-01 to 2024-03-03
# 2024-03-03 20:36:46,783, data_manager.py, 115, INFO, Getting stock price data for MMM from 2000-01-01 to 2024-03-03
# [*********************100%%**********************]  1 of 1 completed
# 2024-03-03 20:36:47,935, data_manager.py, 89, INFO, Saving data for MMM by year
# 2024-03-03 20:36:47,935, data_manager.py, 89, INFO, Saving data for MMM by year
# 2024-03-03 20:36:48,984, data_manager.py, 80, INFO, Processing ticker AOS
# 2024-03-03 20:36:48,984, data_manager.py, 80, INFO, Processing ticker AOS
# 2024-03-03 20:36:48,984, data_manager.py, 115, INFO, Getting stock price data for AOS from 2000-01-01 to 2024-03-03
# 2024-03-03 20:36:48,984, data_manager.py, 115, INFO, Getting stock price data for AOS from 2000-01-01 to 2024-03-03
# [*********************100%%**********************]  1 of 1 completed
# 2024-03-03 20:36:49,334, data_manager.py, 89, INFO, Saving data for AOS by year
# 2024-03-03 20:36:49,334, data_manager.py, 89, INFO, Saving data for AOS by year
# 2024-03-03 20:36:50,445, data_manager.py, 80, INFO, Processing ticker ABT
# 2024-03-03 20:36:50,445, data_manager.py, 80, INFO, Processing ticker ABT
# 2024-03-03 20:36:50,445, data_manager.py, 115, INFO, Getting stock price data for ABT from 2000-01-01 to 2024-03-03
# 2024-03-03 20:36:50,445, data_manager.py, 115, INFO, Getting stock price data for ABT from 2000-01-01 to 2024-03-03
# [*********************100%%**********************]  1 of 1 completed
# 2024-03-03 20:36:51,105, data_manager.py, 89, INFO, Saving data for ABT by year
# 2024-03-03 20:36:51,105, data_manager.py, 89, INFO, Saving data for ABT by year
# 2024-03-03 20:36:52,223, data_manager.py, 80, INFO, Processing ticker ABBV
# 2024-03-03 20:36:52,223, data_manager.py, 80, INFO, Processing ticker ABBV
# 2024-03-03 20:36:52,223, data_manager.py, 115, INFO, Getting stock price data for ABBV from 2000-01-01 to 2024-03-03
# 2024-03-03 20:36:52,223, data_manager.py, 115, INFO, Getting stock price data for ABBV from 2000-01-01 to 2024-03-03
# [*********************100%%**********************]  1 of 1 completed
# 2024-03-03 20:36:52,581, data_manager.py, 89, INFO, Saving data for ABBV by year
# 2024-03-03 20:36:52,581, data_manager.py, 89, INFO, Saving data for ABBV by year
# 2024-03-03 20:36:53,091, data_manager.py, 80, INFO, Processing ticker ACN
# 2024-03-03 20:36:53,091, data_manager.py, 80, INFO, Processing ticker ACN
# 2024-03-03 20:36:53,094, data_manager.py, 115, INFO, Getting stock price data for ACN from 2000-01-01 to 2024-03-03
# 2024-03-03 20:36:53,094, data_manager.py, 115, INFO, Getting stock price data for ACN from 2000-01-01 to 2024-03-03
# [*********************100%%**********************]  1 of 1 completed
# 2024-03-03 20:36:53,571, data_manager.py, 89, INFO, Saving data for ACN by year
# 2024-03-03 20:36:53,571, data_manager.py, 89, INFO, Saving data for ACN by year
# 2024-03-03 20:36:54,606, data_manager.py, 80, INFO, Processing ticker ADBE
# 2024-03-03 20:36:54,606, data_manager.py, 80, INFO, Processing ticker ADBE
# 2024-03-03 20:36:54,620, data_manager.py, 115, INFO, Getting stock price data for ADBE from 2000-01-01 to 2024-03-03
# 2024-03-03 20:36:54,620, data_manager.py, 115, INFO, Getting stock price data for ADBE from 2000-01-01 to 2024-03-03
# [*********************100%%**********************]  1 of 1 completed
# 2024-03-03 20:36:55,137, data_manager.py, 89, INFO, Saving data for ADBE by year
# 2024-03-03 20:36:55,137, data_manager.py, 89, INFO, Saving data for ADBE by year
# 2024-03-03 20:36:56,324, data_manager.py, 80, INFO, Processing ticker AMD
# 2024-03-03 20:36:56,324, data_manager.py, 80, INFO, Processing ticker AMD
# 2024-03-03 20:36:56,331, data_manager.py, 115, INFO, Getting stock price data for AMD from 2000-01-01 to 2024-03-03
# 2024-03-03 20:36:56,331, data_manager.py, 115, INFO, Getting stock price data for AMD from 2000-01-01 to 2024-03-03
# [*********************100%%**********************]  1 of 1 completed
# 2024-03-03 20:36:56,606, data_manager.py, 89, INFO, Saving data for AMD by year
# 2024-03-03 20:36:56,606, data_manager.py, 89, INFO, Saving data for AMD by year
# 2024-03-03 20:36:57,808, data_manager.py, 80, INFO, Processing ticker AES
# 2024-03-03 20:36:57,808, data_manager.py, 80, INFO, Processing ticker AES
# 2024-03-03 20:36:57,808, data_manager.py, 115, INFO, Getting stock price data for AES from 2000-01-01 to 2024-03-03
# 2024-03-03 20:36:57,808, data_manager.py, 115, INFO, Getting stock price data for AES from 2000-01-01 to 2024-03-03
# [*********************100%%**********************]  1 of 1 completed
# 2024-03-03 20:36:58,220, data_manager.py, 89, INFO, Saving data for AES by year
# 2024-03-03 20:36:58,220, data_manager.py, 89, INFO, Saving data for AES by year
# 2024-03-03 20:36:59,309, data_manager.py, 80, INFO, Processing ticker AFL
# 2024-03-03 20:36:59,309, data_manager.py, 80, INFO, Processing ticker AFL
# 2024-03-03 20:36:59,310, data_manager.py, 115, INFO, Getting stock price data for AFL from 2000-01-01 to 2024-03-03
# 2024-03-03 20:36:59,310, data_manager.py, 115, INFO, Getting stock price data for AFL from 2000-01-01 to 2024-03-03
# [*********************100%%**********************]  1 of 1 completed
# 2024-03-03 20:36:59,715, data_manager.py, 89, INFO, Saving data for AFL by year
# 2024-03-03 20:36:59,715, data_manager.py, 89, INFO, Saving data for AFL by year
# 2024-03-03 20:37:00,824, data_manager.py, 80, INFO, Processing ticker A
# 2024-03-03 20:37:00,824, data_manager.py, 80, INFO, Processing ticker A
# 2024-03-03 20:37:00,824, data_manager.py, 115, INFO, Getting stock price data for A from 2000-01-01 to 2024-03-03
# 2024-03-03 20:37:00,824, data_manager.py, 115, INFO, Getting stock price data for A from 2000-01-01 to 2024-03-03
# [*********************100%%**********************]  1 of 1 completed
# 2024-03-03 20:37:01,317, data_manager.py, 89, INFO, Saving data for A by year
# 2024-03-03 20:37:01,317, data_manager.py, 89, INFO, Saving data for A by year
# 2024-03-03 20:37:02,348, data_manager.py, 80, INFO, Processing ticker APD
# 2024-03-03 20:37:02,348, data_manager.py, 80, INFO, Processing ticker APD
# 2024-03-03 20:37:02,348, data_manager.py, 115, INFO, Getting stock price data for APD from 2000-01-01 to 2024-03-03
# 2024-03-03 20:37:02,348, data_manager.py, 115, INFO, Getting stock price data for APD from 2000-01-01 to 2024-03-03
# [*********************100%%**********************]  1 of 1 completed
# 2024-03-03 20:37:03,496, data_manager.py, 89, INFO, Saving data for APD by year
# 2024-03-03 20:37:03,496, data_manager.py, 89, INFO, Saving data for APD by year
# 2024-03-03 20:37:04,531, data_manager.py, 80, INFO, Processing ticker ABNB
# 2024-03-03 20:37:04,531, data_manager.py, 80, INFO, Processing ticker ABNB
# 2024-03-03 20:37:04,531, data_manager.py, 115, INFO, Getting stock price data for ABNB from 2000-01-01 to 2024-03-03
# 2024-03-03 20:37:04,531, data_manager.py, 115, INFO, Getting stock price data for ABNB from 2000-01-01 to 2024-03-03
# [*********************100%%**********************]  1 of 1 completed
# 2024-03-03 20:37:04,718, data_manager.py, 89, INFO, Saving data for ABNB by year
# 2024-03-03 20:37:04,718, data_manager.py, 89, INFO, Saving data for ABNB by year
# 2024-03-03 20:37:04,931, data_manager.py, 80, INFO, Processing ticker AKAM
# 2024-03-03 20:37:04,931, data_manager.py, 80, INFO, Processing ticker AKAM
# 2024-03-03 20:37:04,948, data_manager.py, 115, INFO, Getting stock price data for AKAM from 2000-01-01 to 2024-03-03
# 2024-03-03 20:37:04,948, data_manager.py, 115, INFO, Getting stock price data for AKAM from 2000-01-01 to 2024-03-03
# [*********************100%%**********************]  1 of 1 completed
# 2024-03-03 20:37:05,554, data_manager.py, 89, INFO, Saving data for AKAM by year
# 2024-03-03 20:37:05,554, data_manager.py, 89, INFO, Saving data for AKAM by year
# 2024-03-03 20:37:06,604, data_manager.py, 80, INFO, Processing ticker ALB
# 2024-03-03 20:37:06,604, data_manager.py, 80, INFO, Processing ticker ALB
# 2024-03-03 20:37:06,605, data_manager.py, 115, INFO, Getting stock price data for ALB from 2000-01-01 to 2024-03-03
# 2024-03-03 20:37:06,605, data_manager.py, 115, INFO, Getting stock price data for ALB from 2000-01-01 to 2024-03-03
# [*********************100%%**********************]  1 of 1 completed
# 2024-03-03 20:37:07,096, data_manager.py, 89, INFO, Saving data for ALB by year
# 2024-03-03 20:37:07,096, data_manager.py, 89, INFO, Saving data for ALB by year
# 2024-03-03 20:37:08,152, data_manager.py, 80, INFO, Processing ticker ARE
# 2024-03-03 20:37:08,152, data_manager.py, 80, INFO, Processing ticker ARE
# 2024-03-03 20:37:08,152, data_manager.py, 115, INFO, Getting stock price data for ARE from 2000-01-01 to 2024-03-03
# 2024-03-03 20:37:08,152, data_manager.py, 115, INFO, Getting stock price data for ARE from 2000-01-01 to 2024-03-03
# [*********************100%%**********************]  1 of 1 completed
# 2024-03-03 20:37:08,821, data_manager.py, 89, INFO, Saving data for ARE by year
# 2024-03-03 20:37:08,821, data_manager.py, 89, INFO, Saving data for ARE by year
# 2024-03-03 20:37:09,920, data_manager.py, 80, INFO, Processing ticker ALGN
# 2024-03-03 20:37:09,920, data_manager.py, 80, INFO, Processing ticker ALGN
# 2024-03-03 20:37:09,937, data_manager.py, 115, INFO, Getting stock price data for ALGN from 2000-01-01 to 2024-03-03
# 2024-03-03 20:37:09,937, data_manager.py, 115, INFO, Getting stock price data for ALGN from 2000-01-01 to 2024-03-03
# [*********************100%%**********************]  1 of 1 completed
# 2024-03-03 20:37:10,381, data_manager.py, 89, INFO, Saving data for ALGN by year
# 2024-03-03 20:37:10,381, data_manager.py, 89, INFO, Saving data for ALGN by year
# 2024-03-03 20:37:11,388, data_manager.py, 80, INFO, Processing ticker ALLE
# 2024-03-03 20:37:11,388, data_manager.py, 80, INFO, Processing ticker ALLE
# 2024-03-03 20:37:11,405, data_manager.py, 115, INFO, Getting stock price data for ALLE from 2000-01-01 to 2024-03-03
# 2024-03-03 20:37:11,405, data_manager.py, 115, INFO, Getting stock price data for ALLE from 2000-01-01 to 2024-03-03
# [*********************100%%**********************]  1 of 1 completed
# 2024-03-03 20:37:11,872, data_manager.py, 89, INFO, Saving data for ALLE by year
# 2024-03-03 20:37:11,872, data_manager.py, 89, INFO, Saving data for ALLE by year
# 2024-03-03 20:37:12,406, data_manager.py, 80, INFO, Processing ticker LNT
# 2024-03-03 20:37:12,406, data_manager.py, 80, INFO, Processing ticker LNT
# 2024-03-03 20:37:12,421, data_manager.py, 115, INFO, Getting stock price data for LNT from 2000-01-01 to 2024-03-03
# 2024-03-03 20:37:12,421, data_manager.py, 115, INFO, Getting stock price data for LNT from 2000-01-01 to 2024-03-03
# [*********************100%%**********************]  1 of 1 completed
# 2024-03-03 20:37:13,152, data_manager.py, 89, INFO, Saving data for LNT by year
# 2024-03-03 20:37:13,152, data_manager.py, 89, INFO, Saving data for LNT by year
# 2024-03-03 20:37:14,132, data_manager.py, 80, INFO, Processing ticker ALL
# 2024-03-03 20:37:14,132, data_manager.py, 80, INFO, Processing ticker ALL
# 2024-03-03 20:37:14,132, data_manager.py, 115, INFO, Getting stock price data for ALL from 2000-01-01 to 2024-03-03
# 2024-03-03 20:37:14,132, data_manager.py, 115, INFO, Getting stock price data for ALL from 2000-01-01 to 2024-03-03
# [*********************100%%**********************]  1 of 1 completed
# 2024-03-03 20:37:14,891, data_manager.py, 89, INFO, Saving data for ALL by year
# 2024-03-03 20:37:14,891, data_manager.py, 89, INFO, Saving data for ALL by year
# 2024-03-03 20:37:15,892, data_manager.py, 80, INFO, Processing ticker GOOGL
# 2024-03-03 20:37:15,892, data_manager.py, 80, INFO, Processing ticker GOOGL
# 2024-03-03 20:37:15,892, data_manager.py, 115, INFO, Getting stock price data for GOOGL from 2000-01-01 to 2024-03-03
# 2024-03-03 20:37:15,892, data_manager.py, 115, INFO, Getting stock price data for GOOGL from 2000-01-01 to 2024-03-03
# [*********************100%%**********************]  1 of 1 completed
# 2024-03-03 20:37:16,323, data_manager.py, 89, INFO, Saving data for GOOGL by year
# 2024-03-03 20:37:16,323, data_manager.py, 89, INFO, Saving data for GOOGL by year
# 2024-03-03 20:37:17,227, data_manager.py, 80, INFO, Processing ticker GOOG
# 2024-03-03 20:37:17,227, data_manager.py, 80, INFO, Processing ticker GOOG
# 2024-03-03 20:37:17,227, data_manager.py, 115, INFO, Getting stock price data for GOOG from 2000-01-01 to 2024-03-03
# 2024-03-03 20:37:17,227, data_manager.py, 115, INFO, Getting stock price data for GOOG from 2000-01-01 to 2024-03-03
# [*********************100%%**********************]  1 of 1 completed
# 2024-03-03 20:37:17,565, data_manager.py, 89, INFO, Saving data for GOOG by year
# 2024-03-03 20:37:17,565, data_manager.py, 89, INFO, Saving data for GOOG by year
# 2024-03-03 20:37:18,416, data_manager.py, 80, INFO, Processing ticker MO
# 2024-03-03 20:37:18,416, data_manager.py, 80, INFO, Processing ticker MO
# 2024-03-03 20:37:18,428, data_manager.py, 115, INFO, Getting stock price data for MO from 2000-01-01 to 2024-03-03
# 2024-03-03 20:37:18,428, data_manager.py, 115, INFO, Getting stock price data for MO from 2000-01-01 to 2024-03-03
# [*********************100%%**********************]  1 of 1 completed
# 2024-03-03 20:37:18,828, data_manager.py, 89, INFO, Saving data for MO by year
# 2024-03-03 20:37:18,828, data_manager.py, 89, INFO, Saving data for MO by year
# 2024-03-03 20:37:19,971, data_manager.py, 80, INFO, Processing ticker AMZN
# 2024-03-03 20:37:19,971, data_manager.py, 80, INFO, Processing ticker AMZN
# 2024-03-03 20:37:19,971, data_manager.py, 115, INFO, Getting stock price data for AMZN from 2000-01-01 to 2024-03-03
# 2024-03-03 20:37:19,971, data_manager.py, 115, INFO, Getting stock price data for AMZN from 2000-01-01 to 2024-03-03
# [*********************100%%**********************]  1 of 1 completed
# 2024-03-03 20:37:20,307, data_manager.py, 89, INFO, Saving data for AMZN by year
# 2024-03-03 20:37:20,307, data_manager.py, 89, INFO, Saving data for AMZN by year
# 2024-03-03 20:37:21,431, data_manager.py, 80, INFO, Processing ticker AMCR
# 2024-03-03 20:37:21,431, data_manager.py, 80, INFO, Processing ticker AMCR
# 2024-03-03 20:37:21,434, data_manager.py, 115, INFO, Getting stock price data for AMCR from 2000-01-01 to 2024-03-03
# 2024-03-03 20:37:21,434, data_manager.py, 115, INFO, Getting stock price data for AMCR from 2000-01-01 to 2024-03-03
# [*********************100%%**********************]  1 of 1 completed
# 2024-03-03 20:37:21,873, data_manager.py, 89, INFO, Saving data for AMCR by year
# 2024-03-03 20:37:21,873, data_manager.py, 89, INFO, Saving data for AMCR by year
# 2024-03-03 20:37:22,537, data_manager.py, 80, INFO, Processing ticker AEE
# 2024-03-03 20:37:22,537, data_manager.py, 80, INFO, Processing ticker AEE
# 2024-03-03 20:37:22,537, data_manager.py, 115, INFO, Getting stock price data for AEE from 2000-01-01 to 2024-03-03
# 2024-03-03 20:37:22,537, data_manager.py, 115, INFO, Getting stock price data for AEE from 2000-01-01 to 2024-03-03
# [*********************100%%**********************]  1 of 1 completed
# 2024-03-03 20:37:23,051, data_manager.py, 89, INFO, Saving data for AEE by year
# 2024-03-03 20:37:23,051, data_manager.py, 89, INFO, Saving data for AEE by year
# 2024-03-03 20:37:25,217, data_manager.py, 80, INFO, Processing ticker AAL
# 2024-03-03 20:37:25,217, data_manager.py, 80, INFO, Processing ticker AAL
# 2024-03-03 20:37:25,217, data_manager.py, 115, INFO, Getting stock price data for AAL from 2000-01-01 to 2024-03-03
# 2024-03-03 20:37:25,217, data_manager.py, 115, INFO, Getting stock price data for AAL from 2000-01-01 to 2024-03-03
# [*********************100%%**********************]  1 of 1 completed
# 2024-03-03 20:37:25,629, data_manager.py, 89, INFO, Saving data for AAL by year
# 2024-03-03 20:37:25,629, data_manager.py, 89, INFO, Saving data for AAL by year
# 2024-03-03 20:37:26,477, data_manager.py, 80, INFO, Processing ticker AEP
# 2024-03-03 20:37:26,477, data_manager.py, 80, INFO, Processing ticker AEP
# 2024-03-03 20:37:26,487, data_manager.py, 115, INFO, Getting stock price data for AEP from 2000-01-01 to 2024-03-03
# 2024-03-03 20:37:26,487, data_manager.py, 115, INFO, Getting stock price data for AEP from 2000-01-01 to 2024-03-03
# [*********************100%%**********************]  1 of 1 completed
# 2024-03-03 20:37:27,020, data_manager.py, 89, INFO, Saving data for AEP by year
# 2024-03-03 20:37:27,020, data_manager.py, 89, INFO, Saving data for AEP by year
# 2024-03-03 20:37:28,095, data_manager.py, 80, INFO, Processing ticker AXP
# 2024-03-03 20:37:28,095, data_manager.py, 80, INFO, Processing ticker AXP
# 2024-03-03 20:37:28,106, data_manager.py, 115, INFO, Getting stock price data for AXP from 2000-01-01 to 2024-03-03
# 2024-03-03 20:37:28,106, data_manager.py, 115, INFO, Getting stock price data for AXP from 2000-01-01 to 2024-03-03
# [*********************100%%**********************]  1 of 1 completed
# 2024-03-03 20:37:28,530, data_manager.py, 89, INFO, Saving data for AXP by year
# 2024-03-03 20:37:28,530, data_manager.py, 89, INFO, Saving data for AXP by year
# 2024-03-03 20:37:29,608, data_manager.py, 80, INFO, Processing ticker AIG
# 2024-03-03 20:37:29,608, data_manager.py, 80, INFO, Processing ticker AIG
# 2024-03-03 20:37:29,608, data_manager.py, 115, INFO, Getting stock price data for AIG from 2000-01-01 to 2024-03-03
# 2024-03-03 20:37:29,608, data_manager.py, 115, INFO, Getting stock price data for AIG from 2000-01-01 to 2024-03-03
# [*********************100%%**********************]  1 of 1 completed
# 2024-03-03 20:37:30,190, data_manager.py, 89, INFO, Saving data for AIG by year
# 2024-03-03 20:37:30,190, data_manager.py, 89, INFO, Saving data for AIG by year
# 2024-03-03 20:37:31,224, data_manager.py, 80, INFO, Processing ticker AMT
# 2024-03-03 20:37:31,224, data_manager.py, 80, INFO, Processing ticker AMT
# 2024-03-03 20:37:31,239, data_manager.py, 115, INFO, Getting stock price data for AMT from 2000-01-01 to 2024-03-03
# 2024-03-03 20:37:31,239, data_manager.py, 115, INFO, Getting stock price data for AMT from 2000-01-01 to 2024-03-03
# [*********************100%%**********************]  1 of 1 completed
# 2024-03-03 20:37:31,634, data_manager.py, 89, INFO, Saving data for AMT by year
# 2024-03-03 20:37:31,634, data_manager.py, 89, INFO, Saving data for AMT by year
# 2024-03-03 20:37:32,643, data_manager.py, 80, INFO, Processing ticker AWK
# 2024-03-03 20:37:32,643, data_manager.py, 80, INFO, Processing ticker AWK
# 2024-03-03 20:37:32,645, data_manager.py, 115, INFO, Getting stock price data for AWK from 2000-01-01 to 2024-03-03
# 2024-03-03 20:37:32,645, data_manager.py, 115, INFO, Getting stock price data for AWK from 2000-01-01 to 2024-03-03
# [*********************100%%**********************]  1 of 1 completed
# 2024-03-03 20:37:33,242, data_manager.py, 89, INFO, Saving data for AWK by year
# 2024-03-03 20:37:33,242, data_manager.py, 89, INFO, Saving data for AWK by year
# 2024-03-03 20:37:33,898, data_manager.py, 80, INFO, Processing ticker AMP
# 2024-03-03 20:37:33,898, data_manager.py, 80, INFO, Processing ticker AMP
# 2024-03-03 20:37:33,901, data_manager.py, 115, INFO, Getting stock price data for AMP from 2000-01-01 to 2024-03-03
# 2024-03-03 20:37:33,901, data_manager.py, 115, INFO, Getting stock price data for AMP from 2000-01-01 to 2024-03-03
# [*********************100%%**********************]  1 of 1 completed
# 2024-03-03 20:37:34,527, data_manager.py, 89, INFO, Saving data for AMP by year
# 2024-03-03 20:37:34,527, data_manager.py, 89, INFO, Saving data for AMP by year
# 2024-03-03 20:37:35,312, data_manager.py, 80, INFO, Processing ticker AME
# 2024-03-03 20:37:35,312, data_manager.py, 80, INFO, Processing ticker AME
# 2024-03-03 20:37:35,315, data_manager.py, 115, INFO, Getting stock price data for AME from 2000-01-01 to 2024-03-03
# 2024-03-03 20:37:35,315, data_manager.py, 115, INFO, Getting stock price data for AME from 2000-01-01 to 2024-03-03
# [*********************100%%**********************]  1 of 1 completed
# 2024-03-03 20:37:35,783, data_manager.py, 89, INFO, Saving data for AME by year
# 2024-03-03 20:37:35,783, data_manager.py, 89, INFO, Saving data for AME by year
# 2024-03-03 20:37:36,813, data_manager.py, 80, INFO, Processing ticker AMGN
# 2024-03-03 20:37:36,813, data_manager.py, 80, INFO, Processing ticker AMGN
# 2024-03-03 20:37:36,813, data_manager.py, 115, INFO, Getting stock price data for AMGN from 2000-01-01 to 2024-03-03
# 2024-03-03 20:37:36,813, data_manager.py, 115, INFO, Getting stock price data for AMGN from 2000-01-01 to 2024-03-03
# [*********************100%%**********************]  1 of 1 completed
# 2024-03-03 20:37:37,163, data_manager.py, 89, INFO, Saving data for AMGN by year
# 2024-03-03 20:37:37,163, data_manager.py, 89, INFO, Saving data for AMGN by year
# 2024-03-03 20:37:38,247, data_manager.py, 80, INFO, Processing ticker APH
# 2024-03-03 20:37:38,247, data_manager.py, 80, INFO, Processing ticker APH
# 2024-03-03 20:37:38,247, data_manager.py, 115, INFO, Getting stock price data for APH from 2000-01-01 to 2024-03-03
# 2024-03-03 20:37:38,247, data_manager.py, 115, INFO, Getting stock price data for APH from 2000-01-01 to 2024-03-03
# [*********************100%%**********************]  1 of 1 completed
# 2024-03-03 20:37:38,620, data_manager.py, 89, INFO, Saving data for APH by year
# 2024-03-03 20:37:38,620, data_manager.py, 89, INFO, Saving data for APH by year
# 2024-03-03 20:37:39,709, data_manager.py, 80, INFO, Processing ticker ADI
# 2024-03-03 20:37:39,709, data_manager.py, 80, INFO, Processing ticker ADI
# 2024-03-03 20:37:39,725, data_manager.py, 115, INFO, Getting stock price data for ADI from 2000-01-01 to 2024-03-03
# 2024-03-03 20:37:39,725, data_manager.py, 115, INFO, Getting stock price data for ADI from 2000-01-01 to 2024-03-03
# [*********************100%%**********************]  1 of 1 completed
# 2024-03-03 20:37:40,124, data_manager.py, 89, INFO, Saving data for ADI by year
# 2024-03-03 20:37:40,124, data_manager.py, 89, INFO, Saving data for ADI by year
# 2024-03-03 20:37:41,243, data_manager.py, 80, INFO, Processing ticker ANSS
# 2024-03-03 20:37:41,243, data_manager.py, 80, INFO, Processing ticker ANSS
# 2024-03-03 20:37:41,246, data_manager.py, 115, INFO, Getting stock price data for ANSS from 2000-01-01 to 2024-03-03
# 2024-03-03 20:37:41,246, data_manager.py, 115, INFO, Getting stock price data for ANSS from 2000-01-01 to 2024-03-03
# [*********************100%%**********************]  1 of 1 completed
# 2024-03-03 20:37:41,646, data_manager.py, 89, INFO, Saving data for ANSS by year
# 2024-03-03 20:37:41,646, data_manager.py, 89, INFO, Saving data for ANSS by year
# 2024-03-03 20:37:42,715, data_manager.py, 80, INFO, Processing ticker AON
# 2024-03-03 20:37:42,715, data_manager.py, 80, INFO, Processing ticker AON
# 2024-03-03 20:37:42,733, data_manager.py, 115, INFO, Getting stock price data for AON from 2000-01-01 to 2024-03-03
# 2024-03-03 20:37:42,733, data_manager.py, 115, INFO, Getting stock price data for AON from 2000-01-01 to 2024-03-03
# [*********************100%%**********************]  1 of 1 completed
# 2024-03-03 20:37:43,234, data_manager.py, 89, INFO, Saving data for AON by year
# 2024-03-03 20:37:43,234, data_manager.py, 89, INFO, Saving data for AON by year
# 2024-03-03 20:37:44,437, data_manager.py, 80, INFO, Processing ticker APA
# 2024-03-03 20:37:44,437, data_manager.py, 80, INFO, Processing ticker APA
# 2024-03-03 20:37:44,437, data_manager.py, 115, INFO, Getting stock price data for APA from 2000-01-01 to 2024-03-03
# 2024-03-03 20:37:44,437, data_manager.py, 115, INFO, Getting stock price data for APA from 2000-01-01 to 2024-03-03
# [*********************100%%**********************]  1 of 1 completed
# 2024-03-03 20:37:45,070, data_manager.py, 89, INFO, Saving data for APA by year
# 2024-03-03 20:37:45,070, data_manager.py, 89, INFO, Saving data for APA by year
# 2024-03-03 20:37:46,196, data_manager.py, 80, INFO, Processing ticker AAPL
# 2024-03-03 20:37:46,196, data_manager.py, 80, INFO, Processing ticker AAPL
# 2024-03-03 20:37:46,196, data_manager.py, 115, INFO, Getting stock price data for AAPL from 2000-01-01 to 2024-03-03
# 2024-03-03 20:37:46,196, data_manager.py, 115, INFO, Getting stock price data for AAPL from 2000-01-01 to 2024-03-03
# [*********************100%%**********************]  1 of 1 completed
# 2024-03-03 20:37:46,785, data_manager.py, 89, INFO, Saving data for AAPL by year
# 2024-03-03 20:37:46,785, data_manager.py, 89, INFO, Saving data for AAPL by year
# 2024-03-03 20:37:47,829, data_manager.py, 80, INFO, Processing ticker AMAT
# 2024-03-03 20:37:47,829, data_manager.py, 80, INFO, Processing ticker AMAT
# 2024-03-03 20:37:47,829, data_manager.py, 115, INFO, Getting stock price data for AMAT from 2000-01-01 to 2024-03-03
# 2024-03-03 20:37:47,829, data_manager.py, 115, INFO, Getting stock price data for AMAT from 2000-01-01 to 2024-03-03
# [*********************100%%**********************]  1 of 1 completed
# 2024-03-03 20:37:48,259, data_manager.py, 89, INFO, Saving data for AMAT by year
# 2024-03-03 20:37:48,259, data_manager.py, 89, INFO, Saving data for AMAT by year
# 2024-03-03 20:37:49,274, data_manager.py, 80, INFO, Processing ticker APTV
# 2024-03-03 20:37:49,274, data_manager.py, 80, INFO, Processing ticker APTV
# 2024-03-03 20:37:49,274, data_manager.py, 115, INFO, Getting stock price data for APTV from 2000-01-01 to 2024-03-03
# 2024-03-03 20:37:49,274, data_manager.py, 115, INFO, Getting stock price data for APTV from 2000-01-01 to 2024-03-03
# [*********************100%%**********************]  1 of 1 completed
# 2024-03-03 20:37:49,523, data_manager.py, 89, INFO, Saving data for APTV by year
# 2024-03-03 20:37:49,523, data_manager.py, 89, INFO, Saving data for APTV by year
# 2024-03-03 20:37:50,032, data_manager.py, 80, INFO, Processing ticker ACGL
# 2024-03-03 20:37:50,032, data_manager.py, 80, INFO, Processing ticker ACGL
# 2024-03-03 20:37:50,032, data_manager.py, 115, INFO, Getting stock price data for ACGL from 2000-01-01 to 2024-03-03
# 2024-03-03 20:37:50,032, data_manager.py, 115, INFO, Getting stock price data for ACGL from 2000-01-01 to 2024-03-03
# [*********************100%%**********************]  1 of 1 completed
# 2024-03-03 20:37:50,535, data_manager.py, 89, INFO, Saving data for ACGL by year
# 2024-03-03 20:37:50,535, data_manager.py, 89, INFO, Saving data for ACGL by year
# 2024-03-03 20:37:51,635, data_manager.py, 80, INFO, Processing ticker ADM
# 2024-03-03 20:37:51,635, data_manager.py, 80, INFO, Processing ticker ADM
# 2024-03-03 20:37:51,646, data_manager.py, 115, INFO, Getting stock price data for ADM from 2000-01-01 to 2024-03-03
# 2024-03-03 20:37:51,646, data_manager.py, 115, INFO, Getting stock price data for ADM from 2000-01-01 to 2024-03-03
# [*********************100%%**********************]  1 of 1 completed
# 2024-03-03 20:37:52,222, data_manager.py, 89, INFO, Saving data for ADM by year
# 2024-03-03 20:37:52,222, data_manager.py, 89, INFO, Saving data for ADM by year
# 2024-03-03 20:37:53,263, data_manager.py, 80, INFO, Processing ticker ANET
# 2024-03-03 20:37:53,263, data_manager.py, 80, INFO, Processing ticker ANET
# 2024-03-03 20:37:53,263, data_manager.py, 115, INFO, Getting stock price data for ANET from 2000-01-01 to 2024-03-03
# 2024-03-03 20:37:53,263, data_manager.py, 115, INFO, Getting stock price data for ANET from 2000-01-01 to 2024-03-03
# [*********************100%%**********************]  1 of 1 completed
# 2024-03-03 20:37:53,739, data_manager.py, 89, INFO, Saving data for ANET by year
# 2024-03-03 20:37:53,739, data_manager.py, 89, INFO, Saving data for ANET by year
# 2024-03-03 20:37:54,180, data_manager.py, 80, INFO, Processing ticker AJG
# 2024-03-03 20:37:54,180, data_manager.py, 80, INFO, Processing ticker AJG
# 2024-03-03 20:37:54,180, data_manager.py, 115, INFO, Getting stock price data for AJG from 2000-01-01 to 2024-03-03
# 2024-03-03 20:37:54,180, data_manager.py, 115, INFO, Getting stock price data for AJG from 2000-01-01 to 2024-03-03
# [*********************100%%**********************]  1 of 1 completed
# 2024-03-03 20:37:54,981, data_manager.py, 89, INFO, Saving data for AJG by year
# 2024-03-03 20:37:54,981, data_manager.py, 89, INFO, Saving data for AJG by year
# 2024-03-03 20:37:55,933, data_manager.py, 80, INFO, Processing ticker AIZ
# 2024-03-03 20:37:55,933, data_manager.py, 80, INFO, Processing ticker AIZ
# 2024-03-03 20:37:55,936, data_manager.py, 115, INFO, Getting stock price data for AIZ from 2000-01-01 to 2024-03-03
# 2024-03-03 20:37:55,936, data_manager.py, 115, INFO, Getting stock price data for AIZ from 2000-01-01 to 2024-03-03
# [*********************100%%**********************]  1 of 1 completed
# 2024-03-03 20:37:56,301, data_manager.py, 89, INFO, Saving data for AIZ by year
# 2024-03-03 20:37:56,301, data_manager.py, 89, INFO, Saving data for AIZ by year
# 2024-03-03 20:37:57,557, data_manager.py, 80, INFO, Processing ticker T
# 2024-03-03 20:37:57,557, data_manager.py, 80, INFO, Processing ticker T
# 2024-03-03 20:37:57,560, data_manager.py, 115, INFO, Getting stock price data for T from 2000-01-01 to 2024-03-03
# 2024-03-03 20:37:57,560, data_manager.py, 115, INFO, Getting stock price data for T from 2000-01-01 to 2024-03-03
# [*********************100%%**********************]  1 of 1 completed
# 2024-03-03 20:37:58,051, data_manager.py, 89, INFO, Saving data for T by year
# 2024-03-03 20:37:58,051, data_manager.py, 89, INFO, Saving data for T by year
# 2024-03-03 20:37:59,154, data_manager.py, 80, INFO, Processing ticker ATO
# 2024-03-03 20:37:59,154, data_manager.py, 80, INFO, Processing ticker ATO
# 2024-03-03 20:37:59,154, data_manager.py, 115, INFO, Getting stock price data for ATO from 2000-01-01 to 2024-03-03
# 2024-03-03 20:37:59,154, data_manager.py, 115, INFO, Getting stock price data for ATO from 2000-01-01 to 2024-03-03
# [*********************100%%**********************]  1 of 1 completed
# 2024-03-03 20:37:59,557, data_manager.py, 89, INFO, Saving data for ATO by year
# 2024-03-03 20:37:59,557, data_manager.py, 89, INFO, Saving data for ATO by year
# 2024-03-03 20:38:01,925, data_manager.py, 80, INFO, Processing ticker ADSK
# 2024-03-03 20:38:01,925, data_manager.py, 80, INFO, Processing ticker ADSK
# 2024-03-03 20:38:01,925, data_manager.py, 115, INFO, Getting stock price data for ADSK from 2000-01-01 to 2024-03-03
# 2024-03-03 20:38:01,925, data_manager.py, 115, INFO, Getting stock price data for ADSK from 2000-01-01 to 2024-03-03
# [*********************100%%**********************]  1 of 1 completed
# 2024-03-03 20:38:02,542, data_manager.py, 89, INFO, Saving data for ADSK by year
# 2024-03-03 20:38:02,542, data_manager.py, 89, INFO, Saving data for ADSK by year
# 2024-03-03 20:38:03,617, data_manager.py, 80, INFO, Processing ticker ADP
# 2024-03-03 20:38:03,617, data_manager.py, 80, INFO, Processing ticker ADP
# 2024-03-03 20:38:03,617, data_manager.py, 115, INFO, Getting stock price data for ADP from 2000-01-01 to 2024-03-03
# 2024-03-03 20:38:03,617, data_manager.py, 115, INFO, Getting stock price data for ADP from 2000-01-01 to 2024-03-03
# [*********************100%%**********************]  1 of 1 completed
# 2024-03-03 20:38:04,898, data_manager.py, 89, INFO, Saving data for ADP by year
# 2024-03-03 20:38:04,898, data_manager.py, 89, INFO, Saving data for ADP by year
# 2024-03-03 20:38:05,980, data_manager.py, 80, INFO, Processing ticker AZO
# 2024-03-03 20:38:05,980, data_manager.py, 80, INFO, Processing ticker AZO
# 2024-03-03 20:38:05,980, data_manager.py, 115, INFO, Getting stock price data for AZO from 2000-01-01 to 2024-03-03
# 2024-03-03 20:38:05,980, data_manager.py, 115, INFO, Getting stock price data for AZO from 2000-01-01 to 2024-03-03
# [*********************100%%**********************]  1 of 1 completed
# 2024-03-03 20:38:06,289, data_manager.py, 89, INFO, Saving data for AZO by year
# 2024-03-03 20:38:06,289, data_manager.py, 89, INFO, Saving data for AZO by year
# 2024-03-03 20:38:07,447, data_manager.py, 80, INFO, Processing ticker AVB
# 2024-03-03 20:38:07,447, data_manager.py, 80, INFO, Processing ticker AVB
# 2024-03-03 20:38:07,463, data_manager.py, 115, INFO, Getting stock price data for AVB from 2000-01-01 to 2024-03-03
# 2024-03-03 20:38:07,463, data_manager.py, 115, INFO, Getting stock price data for AVB from 2000-01-01 to 2024-03-03
# [*********************100%%**********************]  1 of 1 completed
# 2024-03-03 20:38:07,868, data_manager.py, 89, INFO, Saving data for AVB by year
# 2024-03-03 20:38:07,868, data_manager.py, 89, INFO, Saving data for AVB by year
# 2024-03-03 20:38:08,986, data_manager.py, 80, INFO, Processing ticker AVY
# 2024-03-03 20:38:08,986, data_manager.py, 80, INFO, Processing ticker AVY
# 2024-03-03 20:38:08,986, data_manager.py, 115, INFO, Getting stock price data for AVY from 2000-01-01 to 2024-03-03
# 2024-03-03 20:38:08,986, data_manager.py, 115, INFO, Getting stock price data for AVY from 2000-01-01 to 2024-03-03
# [*********************100%%**********************]  1 of 1 completed
# 2024-03-03 20:38:09,412, data_manager.py, 89, INFO, Saving data for AVY by year
# 2024-03-03 20:38:09,412, data_manager.py, 89, INFO, Saving data for AVY by year
# 2024-03-03 20:38:10,732, data_manager.py, 80, INFO, Processing ticker AXON
# 2024-03-03 20:38:10,732, data_manager.py, 80, INFO, Processing ticker AXON
# 2024-03-03 20:38:10,732, data_manager.py, 115, INFO, Getting stock price data for AXON from 2000-01-01 to 2024-03-03
# 2024-03-03 20:38:10,732, data_manager.py, 115, INFO, Getting stock price data for AXON from 2000-01-01 to 2024-03-03
# [*********************100%%**********************]  1 of 1 completed
# 2024-03-03 20:38:11,177, data_manager.py, 89, INFO, Saving data for AXON by year
# 2024-03-03 20:38:11,177, data_manager.py, 89, INFO, Saving data for AXON by year
# 2024-03-03 20:38:12,256, data_manager.py, 80, INFO, Processing ticker BKR
# 2024-03-03 20:38:12,256, data_manager.py, 80, INFO, Processing ticker BKR
# 2024-03-03 20:38:12,258, data_manager.py, 115, INFO, Getting stock price data for BKR from 2000-01-01 to 2024-03-03
# 2024-03-03 20:38:12,258, data_manager.py, 115, INFO, Getting stock price data for BKR from 2000-01-01 to 2024-03-03
# [*********************100%%**********************]  1 of 1 completed
# 2024-03-03 20:38:13,058, data_manager.py, 89, INFO, Saving data for BKR by year
# 2024-03-03 20:38:13,058, data_manager.py, 89, INFO, Saving data for BKR by year
# 2024-03-03 20:38:14,327, data_manager.py, 80, INFO, Processing ticker BALL
# 2024-03-03 20:38:14,327, data_manager.py, 80, INFO, Processing ticker BALL
# 2024-03-03 20:38:14,330, data_manager.py, 115, INFO, Getting stock price data for BALL from 2000-01-01 to 2024-03-03
# 2024-03-03 20:38:14,330, data_manager.py, 115, INFO, Getting stock price data for BALL from 2000-01-01 to 2024-03-03
# [*********************100%%**********************]  1 of 1 completed
# 2024-03-03 20:38:15,057, data_manager.py, 89, INFO, Saving data for BALL by year
# 2024-03-03 20:38:15,057, data_manager.py, 89, INFO, Saving data for BALL by year
# 2024-03-03 20:38:15,985, data_manager.py, 80, INFO, Processing ticker BAC
# 2024-03-03 20:38:15,985, data_manager.py, 80, INFO, Processing ticker BAC
# 2024-03-03 20:38:15,985, data_manager.py, 115, INFO, Getting stock price data for BAC from 2000-01-01 to 2024-03-03
# 2024-03-03 20:38:15,985, data_manager.py, 115, INFO, Getting stock price data for BAC from 2000-01-01 to 2024-03-03
# [*********************100%%**********************]  1 of 1 completed
# 2024-03-03 20:38:16,497, data_manager.py, 89, INFO, Saving data for BAC by year
# 2024-03-03 20:38:16,497, data_manager.py, 89, INFO, Saving data for BAC by year
# 2024-03-03 20:38:17,515, data_manager.py, 80, INFO, Processing ticker BK
# 2024-03-03 20:38:17,515, data_manager.py, 80, INFO, Processing ticker BK
# 2024-03-03 20:38:17,515, data_manager.py, 115, INFO, Getting stock price data for BK from 2000-01-01 to 2024-03-03
# 2024-03-03 20:38:17,515, data_manager.py, 115, INFO, Getting stock price data for BK from 2000-01-01 to 2024-03-03
# [*********************100%%**********************]  1 of 1 completed
# 2024-03-03 20:38:17,988, data_manager.py, 89, INFO, Saving data for BK by year
# 2024-03-03 20:38:17,988, data_manager.py, 89, INFO, Saving data for BK by year
# 2024-03-03 20:38:19,029, data_manager.py, 80, INFO, Processing ticker BBWI
# 2024-03-03 20:38:19,029, data_manager.py, 80, INFO, Processing ticker BBWI
# 2024-03-03 20:38:19,032, data_manager.py, 115, INFO, Getting stock price data for BBWI from 2000-01-01 to 2024-03-03
# 2024-03-03 20:38:19,032, data_manager.py, 115, INFO, Getting stock price data for BBWI from 2000-01-01 to 2024-03-03
# [*********************100%%**********************]  1 of 1 completed
# 2024-03-03 20:38:19,525, data_manager.py, 89, INFO, Saving data for BBWI by year
# 2024-03-03 20:38:19,525, data_manager.py, 89, INFO, Saving data for BBWI by year
# 2024-03-03 20:38:20,623, data_manager.py, 80, INFO, Processing ticker BAX
# 2024-03-03 20:38:20,623, data_manager.py, 80, INFO, Processing ticker BAX
# 2024-03-03 20:38:20,625, data_manager.py, 115, INFO, Getting stock price data for BAX from 2000-01-01 to 2024-03-03
# 2024-03-03 20:38:20,625, data_manager.py, 115, INFO, Getting stock price data for BAX from 2000-01-01 to 2024-03-03
# [*********************100%%**********************]  1 of 1 completed
# 2024-03-03 20:38:21,180, data_manager.py, 89, INFO, Saving data for BAX by year
# 2024-03-03 20:38:21,180, data_manager.py, 89, INFO, Saving data for BAX by year
# 2024-03-03 20:38:22,211, data_manager.py, 80, INFO, Processing ticker BDX
# 2024-03-03 20:38:22,211, data_manager.py, 80, INFO, Processing ticker BDX
# 2024-03-03 20:38:22,214, data_manager.py, 115, INFO, Getting stock price data for BDX from 2000-01-01 to 2024-03-03
# 2024-03-03 20:38:22,214, data_manager.py, 115, INFO, Getting stock price data for BDX from 2000-01-01 to 2024-03-03
# [*********************100%%**********************]  1 of 1 completed
# 2024-03-03 20:38:22,901, data_manager.py, 89, INFO, Saving data for BDX by year
# 2024-03-03 20:38:22,901, data_manager.py, 89, INFO, Saving data for BDX by year
# 2024-03-03 20:38:23,915, data_manager.py, 80, INFO, Processing ticker BRK.B
# 2024-03-03 20:38:23,915, data_manager.py, 80, INFO, Processing ticker BRK.B
# 2024-03-03 20:38:23,915, data_manager.py, 115, INFO, Getting stock price data for BRK.B from 2000-01-01 to 2024-03-03
# 2024-03-03 20:38:23,915, data_manager.py, 115, INFO, Getting stock price data for BRK.B from 2000-01-01 to 2024-03-03
# [*********************100%%**********************]  1 of 1 completed
#
# 1 Failed download:
# ['BRK.B']: Exception('%ticker%: No timezone found, symbol may be delisted')
# 2024-03-03 20:38:28,275, data_manager.py, 89, INFO, Saving data for BRK.B by year
# 2024-03-03 20:38:28,275, data_manager.py, 89, INFO, Saving data for BRK.B by year
# 2024-03-03 20:38:28,275, data_manager.py, 107, WARNING, No data found for BRK.B
# 2024-03-03 20:38:28,275, data_manager.py, 107, WARNING, No data found for BRK.B
# 2024-03-03 20:38:28,275, data_manager.py, 80, INFO, Processing ticker BBY
# 2024-03-03 20:38:28,275, data_manager.py, 80, INFO, Processing ticker BBY
# 2024-03-03 20:38:28,275, data_manager.py, 115, INFO, Getting stock price data for BBY from 2000-01-01 to 2024-03-03
# 2024-03-03 20:38:28,275, data_manager.py, 115, INFO, Getting stock price data for BBY from 2000-01-01 to 2024-03-03
# [*********************100%%**********************]  1 of 1 completed
# 2024-03-03 20:38:28,723, data_manager.py, 89, INFO, Saving data for BBY by year
# 2024-03-03 20:38:28,723, data_manager.py, 89, INFO, Saving data for BBY by year
# 2024-03-03 20:38:29,591, data_manager.py, 80, INFO, Processing ticker BIO
# 2024-03-03 20:38:29,591, data_manager.py, 80, INFO, Processing ticker BIO
# 2024-03-03 20:38:29,591, data_manager.py, 115, INFO, Getting stock price data for BIO from 2000-01-01 to 2024-03-03
# 2024-03-03 20:38:29,591, data_manager.py, 115, INFO, Getting stock price data for BIO from 2000-01-01 to 2024-03-03
# [*********************100%%**********************]  1 of 1 completed
# 2024-03-03 20:38:29,951, data_manager.py, 89, INFO, Saving data for BIO by year
# 2024-03-03 20:38:29,951, data_manager.py, 89, INFO, Saving data for BIO by year
# 2024-03-03 20:38:30,946, data_manager.py, 80, INFO, Processing ticker TECH
# 2024-03-03 20:38:30,946, data_manager.py, 80, INFO, Processing ticker TECH
# 2024-03-03 20:38:30,948, data_manager.py, 115, INFO, Getting stock price data for TECH from 2000-01-01 to 2024-03-03
# 2024-03-03 20:38:30,948, data_manager.py, 115, INFO, Getting stock price data for TECH from 2000-01-01 to 2024-03-03
# [*********************100%%**********************]  1 of 1 completed
# 2024-03-03 20:38:31,387, data_manager.py, 89, INFO, Saving data for TECH by year
# 2024-03-03 20:38:31,387, data_manager.py, 89, INFO, Saving data for TECH by year
# 2024-03-03 20:38:32,337, data_manager.py, 80, INFO, Processing ticker BIIB
# 2024-03-03 20:38:32,337, data_manager.py, 80, INFO, Processing ticker BIIB
# 2024-03-03 20:38:32,337, data_manager.py, 115, INFO, Getting stock price data for BIIB from 2000-01-01 to 2024-03-03
# 2024-03-03 20:38:32,337, data_manager.py, 115, INFO, Getting stock price data for BIIB from 2000-01-01 to 2024-03-03
# [*********************100%%**********************]  1 of 1 completed
# 2024-03-03 20:38:32,752, data_manager.py, 89, INFO, Saving data for BIIB by year
# 2024-03-03 20:38:32,752, data_manager.py, 89, INFO, Saving data for BIIB by year
# 2024-03-03 20:38:33,735, data_manager.py, 80, INFO, Processing ticker BLK
# 2024-03-03 20:38:33,735, data_manager.py, 80, INFO, Processing ticker BLK
# 2024-03-03 20:38:33,738, data_manager.py, 115, INFO, Getting stock price data for BLK from 2000-01-01 to 2024-03-03
# 2024-03-03 20:38:33,738, data_manager.py, 115, INFO, Getting stock price data for BLK from 2000-01-01 to 2024-03-03
# [*********************100%%**********************]  1 of 1 completed
# 2024-03-03 20:38:34,366, data_manager.py, 89, INFO, Saving data for BLK by year
# 2024-03-03 20:38:34,366, data_manager.py, 89, INFO, Saving data for BLK by year
# 2024-03-03 20:38:35,328, data_manager.py, 80, INFO, Processing ticker BX
# 2024-03-03 20:38:35,328, data_manager.py, 80, INFO, Processing ticker BX
# 2024-03-03 20:38:35,328, data_manager.py, 115, INFO, Getting stock price data for BX from 2000-01-01 to 2024-03-03
# 2024-03-03 20:38:35,328, data_manager.py, 115, INFO, Getting stock price data for BX from 2000-01-01 to 2024-03-03
# [*********************100%%**********************]  1 of 1 completed
# 2024-03-03 20:38:35,675, data_manager.py, 89, INFO, Saving data for BX by year
# 2024-03-03 20:38:35,675, data_manager.py, 89, INFO, Saving data for BX by year
# 2024-03-03 20:38:36,387, data_manager.py, 80, INFO, Processing ticker BA
# 2024-03-03 20:38:36,387, data_manager.py, 80, INFO, Processing ticker BA
# 2024-03-03 20:38:36,389, data_manager.py, 115, INFO, Getting stock price data for BA from 2000-01-01 to 2024-03-03
# 2024-03-03 20:38:36,389, data_manager.py, 115, INFO, Getting stock price data for BA from 2000-01-01 to 2024-03-03
# [*********************100%%**********************]  1 of 1 completed
# 2024-03-03 20:38:36,808, data_manager.py, 89, INFO, Saving data for BA by year
# 2024-03-03 20:38:36,808, data_manager.py, 89, INFO, Saving data for BA by year
# 2024-03-03 20:38:37,848, data_manager.py, 80, INFO, Processing ticker BKNG
# 2024-03-03 20:38:37,848, data_manager.py, 80, INFO, Processing ticker BKNG
# 2024-03-03 20:38:37,848, data_manager.py, 115, INFO, Getting stock price data for BKNG from 2000-01-01 to 2024-03-03
# 2024-03-03 20:38:37,848, data_manager.py, 115, INFO, Getting stock price data for BKNG from 2000-01-01 to 2024-03-03
# [*********************100%%**********************]  1 of 1 completed
# 2024-03-03 20:38:38,152, data_manager.py, 89, INFO, Saving data for BKNG by year
# 2024-03-03 20:38:38,152, data_manager.py, 89, INFO, Saving data for BKNG by year
# 2024-03-03 20:38:39,198, data_manager.py, 80, INFO, Processing ticker BWA
# 2024-03-03 20:38:39,198, data_manager.py, 80, INFO, Processing ticker BWA
# 2024-03-03 20:38:39,201, data_manager.py, 115, INFO, Getting stock price data for BWA from 2000-01-01 to 2024-03-03
# 2024-03-03 20:38:39,201, data_manager.py, 115, INFO, Getting stock price data for BWA from 2000-01-01 to 2024-03-03
# [*********************100%%**********************]  1 of 1 completed
# 2024-03-03 20:38:39,688, data_manager.py, 89, INFO, Saving data for BWA by year
# 2024-03-03 20:38:39,688, data_manager.py, 89, INFO, Saving data for BWA by year
# 2024-03-03 20:38:40,680, data_manager.py, 80, INFO, Processing ticker BXP
# 2024-03-03 20:38:40,680, data_manager.py, 80, INFO, Processing ticker BXP
# 2024-03-03 20:38:40,683, data_manager.py, 115, INFO, Getting stock price data for BXP from 2000-01-01 to 2024-03-03
# 2024-03-03 20:38:40,683, data_manager.py, 115, INFO, Getting stock price data for BXP from 2000-01-01 to 2024-03-03
# [*********************100%%**********************]  1 of 1 completed
# 2024-03-03 20:38:41,030, data_manager.py, 89, INFO, Saving data for BXP by year
# 2024-03-03 20:38:41,030, data_manager.py, 89, INFO, Saving data for BXP by year
# 2024-03-03 20:38:42,062, data_manager.py, 80, INFO, Processing ticker BSX
# 2024-03-03 20:38:42,062, data_manager.py, 80, INFO, Processing ticker BSX
# 2024-03-03 20:38:42,062, data_manager.py, 115, INFO, Getting stock price data for BSX from 2000-01-01 to 2024-03-03
# 2024-03-03 20:38:42,062, data_manager.py, 115, INFO, Getting stock price data for BSX from 2000-01-01 to 2024-03-03
# [*********************100%%**********************]  1 of 1 completed
# 2024-03-03 20:38:42,539, data_manager.py, 89, INFO, Saving data for BSX by year
# 2024-03-03 20:38:42,539, data_manager.py, 89, INFO, Saving data for BSX by year
# 2024-03-03 20:38:43,694, data_manager.py, 80, INFO, Processing ticker BMY
# 2024-03-03 20:38:43,694, data_manager.py, 80, INFO, Processing ticker BMY
# 2024-03-03 20:38:43,694, data_manager.py, 115, INFO, Getting stock price data for BMY from 2000-01-01 to 2024-03-03
# 2024-03-03 20:38:43,694, data_manager.py, 115, INFO, Getting stock price data for BMY from 2000-01-01 to 2024-03-03
# [*********************100%%**********************]  1 of 1 completed
# 2024-03-03 20:38:44,395, data_manager.py, 89, INFO, Saving data for BMY by year
# 2024-03-03 20:38:44,395, data_manager.py, 89, INFO, Saving data for BMY by year
# 2024-03-03 20:38:45,450, data_manager.py, 80, INFO, Processing ticker AVGO
# 2024-03-03 20:38:45,450, data_manager.py, 80, INFO, Processing ticker AVGO
# 2024-03-03 20:38:45,450, data_manager.py, 115, INFO, Getting stock price data for AVGO from 2000-01-01 to 2024-03-03
# 2024-03-03 20:38:45,450, data_manager.py, 115, INFO, Getting stock price data for AVGO from 2000-01-01 to 2024-03-03
# [*********************100%%**********************]  1 of 1 completed
# 2024-03-03 20:38:45,765, data_manager.py, 89, INFO, Saving data for AVGO by year
# 2024-03-03 20:38:45,765, data_manager.py, 89, INFO, Saving data for AVGO by year
# 2024-03-03 20:38:46,503, data_manager.py, 80, INFO, Processing ticker BR
# 2024-03-03 20:38:46,503, data_manager.py, 80, INFO, Processing ticker BR
# 2024-03-03 20:38:46,503, data_manager.py, 115, INFO, Getting stock price data for BR from 2000-01-01 to 2024-03-03
# 2024-03-03 20:38:46,503, data_manager.py, 115, INFO, Getting stock price data for BR from 2000-01-01 to 2024-03-03
# [*********************100%%**********************]  1 of 1 completed
# 2024-03-03 20:38:46,791, data_manager.py, 89, INFO, Saving data for BR by year
# 2024-03-03 20:38:46,791, data_manager.py, 89, INFO, Saving data for BR by year
# 2024-03-03 20:38:47,599, data_manager.py, 80, INFO, Processing ticker BRO
# 2024-03-03 20:38:47,599, data_manager.py, 80, INFO, Processing ticker BRO
# ...
# 2024-03-03 20:48:54,949, data_manager.py, 89, INFO, Saving data for VMC by year
# 2024-03-03 20:48:56,030, data_manager.py, 80, INFO, Processing ticker WRB
# 2024-03-03 20:48:56,030, data_manager.py, 80, INFO, Processing ticker WRB
# 2024-03-03 20:48:56,030, data_manager.py, 115, INFO, Getting stock price data for WRB from 2000-01-01 to 2024-03-03
# 2024-03-03 20:48:56,030, data_manager.py, 115, INFO, Getting stock price data for WRB from 2000-01-01 to 2024-03-03
# [*********************100%%**********************]  1 of 1 completed
# 2024-03-03 20:48:56,473, data_manager.py, 89, INFO, Saving data for WRB by year
# 2024-03-03 20:48:56,473, data_manager.py, 89, INFO, Saving data for WRB by year
# 2024-03-03 20:48:57,655, data_manager.py, 80, INFO, Processing ticker WAB
# 2024-03-03 20:48:57,655, data_manager.py, 80, INFO, Processing ticker WAB
# 2024-03-03 20:48:57,655, data_manager.py, 115, INFO, Getting stock price data for WAB from 2000-01-01 to 2024-03-03
# 2024-03-03 20:48:57,655, data_manager.py, 115, INFO, Getting stock price data for WAB from 2000-01-01 to 2024-03-03
# [*********************100%%**********************]  1 of 1 completed
# 2024-03-03 20:48:58,099, data_manager.py, 89, INFO, Saving data for WAB by year
# 2024-03-03 20:48:58,099, data_manager.py, 89, INFO, Saving data for WAB by year
# 2024-03-03 20:48:59,257, data_manager.py, 80, INFO, Processing ticker WBA
# 2024-03-03 20:48:59,257, data_manager.py, 80, INFO, Processing ticker WBA
# 2024-03-03 20:48:59,257, data_manager.py, 115, INFO, Getting stock price data for WBA from 2000-01-01 to 2024-03-03
# 2024-03-03 20:48:59,257, data_manager.py, 115, INFO, Getting stock price data for WBA from 2000-01-01 to 2024-03-03
# [*********************100%%**********************]  1 of 1 completed
# 2024-03-03 20:48:59,623, data_manager.py, 89, INFO, Saving data for WBA by year
# 2024-03-03 20:48:59,623, data_manager.py, 89, INFO, Saving data for WBA by year
# 2024-03-03 20:49:00,766, data_manager.py, 80, INFO, Processing ticker WMT
# 2024-03-03 20:49:00,766, data_manager.py, 80, INFO, Processing ticker WMT
# 2024-03-03 20:49:00,766, data_manager.py, 115, INFO, Getting stock price data for WMT from 2000-01-01 to 2024-03-03
# 2024-03-03 20:49:00,766, data_manager.py, 115, INFO, Getting stock price data for WMT from 2000-01-01 to 2024-03-03
# [*********************100%%**********************]  1 of 1 completed
# 2024-03-03 20:49:01,278, data_manager.py, 89, INFO, Saving data for WMT by year
# 2024-03-03 20:49:01,278, data_manager.py, 89, INFO, Saving data for WMT by year
# 2024-03-03 20:49:02,385, data_manager.py, 80, INFO, Processing ticker DIS
# 2024-03-03 20:49:02,385, data_manager.py, 80, INFO, Processing ticker DIS
# 2024-03-03 20:49:02,388, data_manager.py, 115, INFO, Getting stock price data for DIS from 2000-01-01 to 2024-03-03
# 2024-03-03 20:49:02,388, data_manager.py, 115, INFO, Getting stock price data for DIS from 2000-01-01 to 2024-03-03
# [*********************100%%**********************]  1 of 1 completed
# 2024-03-03 20:49:02,985, data_manager.py, 89, INFO, Saving data for DIS by year
# 2024-03-03 20:49:02,985, data_manager.py, 89, INFO, Saving data for DIS by year
# 2024-03-03 20:49:04,104, data_manager.py, 80, INFO, Processing ticker WBD
# 2024-03-03 20:49:04,104, data_manager.py, 80, INFO, Processing ticker WBD
# 2024-03-03 20:49:04,104, data_manager.py, 115, INFO, Getting stock price data for WBD from 2000-01-01 to 2024-03-03
# 2024-03-03 20:49:04,104, data_manager.py, 115, INFO, Getting stock price data for WBD from 2000-01-01 to 2024-03-03
# [*********************100%%**********************]  1 of 1 completed
# 2024-03-03 20:49:04,580, data_manager.py, 89, INFO, Saving data for WBD by year
# 2024-03-03 20:49:04,580, data_manager.py, 89, INFO, Saving data for WBD by year
# 2024-03-03 20:49:05,465, data_manager.py, 80, INFO, Processing ticker WM
# 2024-03-03 20:49:05,465, data_manager.py, 80, INFO, Processing ticker WM
# 2024-03-03 20:49:05,465, data_manager.py, 115, INFO, Getting stock price data for WM from 2000-01-01 to 2024-03-03
# 2024-03-03 20:49:05,465, data_manager.py, 115, INFO, Getting stock price data for WM from 2000-01-01 to 2024-03-03
# [*********************100%%**********************]  1 of 1 completed
# 2024-03-03 20:49:05,875, data_manager.py, 89, INFO, Saving data for WM by year
# 2024-03-03 20:49:05,875, data_manager.py, 89, INFO, Saving data for WM by year
# 2024-03-03 20:49:06,894, data_manager.py, 80, INFO, Processing ticker WAT
# 2024-03-03 20:49:06,894, data_manager.py, 80, INFO, Processing ticker WAT
# 2024-03-03 20:49:06,906, data_manager.py, 115, INFO, Getting stock price data for WAT from 2000-01-01 to 2024-03-03
# 2024-03-03 20:49:06,906, data_manager.py, 115, INFO, Getting stock price data for WAT from 2000-01-01 to 2024-03-03
# [*********************100%%**********************]  1 of 1 completed
# 2024-03-03 20:49:07,169, data_manager.py, 89, INFO, Saving data for WAT by year
# 2024-03-03 20:49:07,169, data_manager.py, 89, INFO, Saving data for WAT by year
# 2024-03-03 20:49:08,217, data_manager.py, 80, INFO, Processing ticker WEC
# 2024-03-03 20:49:08,217, data_manager.py, 80, INFO, Processing ticker WEC
# 2024-03-03 20:49:08,217, data_manager.py, 115, INFO, Getting stock price data for WEC from 2000-01-01 to 2024-03-03
# 2024-03-03 20:49:08,217, data_manager.py, 115, INFO, Getting stock price data for WEC from 2000-01-01 to 2024-03-03
# [*********************100%%**********************]  1 of 1 completed
# 2024-03-03 20:49:08,627, data_manager.py, 89, INFO, Saving data for WEC by year
# 2024-03-03 20:49:08,627, data_manager.py, 89, INFO, Saving data for WEC by year
# 2024-03-03 20:49:09,664, data_manager.py, 80, INFO, Processing ticker WFC
# 2024-03-03 20:49:09,664, data_manager.py, 80, INFO, Processing ticker WFC
# 2024-03-03 20:49:09,667, data_manager.py, 115, INFO, Getting stock price data for WFC from 2000-01-01 to 2024-03-03
# 2024-03-03 20:49:09,667, data_manager.py, 115, INFO, Getting stock price data for WFC from 2000-01-01 to 2024-03-03
# [*********************100%%**********************]  1 of 1 completed
# 2024-03-03 20:49:10,102, data_manager.py, 89, INFO, Saving data for WFC by year
# 2024-03-03 20:49:10,102, data_manager.py, 89, INFO, Saving data for WFC by year
# 2024-03-03 20:49:11,190, data_manager.py, 80, INFO, Processing ticker WELL
# 2024-03-03 20:49:11,190, data_manager.py, 80, INFO, Processing ticker WELL
# 2024-03-03 20:49:11,190, data_manager.py, 115, INFO, Getting stock price data for WELL from 2000-01-01 to 2024-03-03
# 2024-03-03 20:49:11,190, data_manager.py, 115, INFO, Getting stock price data for WELL from 2000-01-01 to 2024-03-03
# [*********************100%%**********************]  1 of 1 completed
# 2024-03-03 20:49:11,610, data_manager.py, 89, INFO, Saving data for WELL by year
# 2024-03-03 20:49:11,610, data_manager.py, 89, INFO, Saving data for WELL by year
# 2024-03-03 20:49:12,722, data_manager.py, 80, INFO, Processing ticker WST
# 2024-03-03 20:49:12,722, data_manager.py, 80, INFO, Processing ticker WST
# 2024-03-03 20:49:12,729, data_manager.py, 115, INFO, Getting stock price data for WST from 2000-01-01 to 2024-03-03
# 2024-03-03 20:49:12,729, data_manager.py, 115, INFO, Getting stock price data for WST from 2000-01-01 to 2024-03-03
# [*********************100%%**********************]  1 of 1 completed
# 2024-03-03 20:49:13,324, data_manager.py, 89, INFO, Saving data for WST by year
# 2024-03-03 20:49:13,324, data_manager.py, 89, INFO, Saving data for WST by year
# 2024-03-03 20:49:14,429, data_manager.py, 80, INFO, Processing ticker WDC
# 2024-03-03 20:49:14,429, data_manager.py, 80, INFO, Processing ticker WDC
# 2024-03-03 20:49:14,432, data_manager.py, 115, INFO, Getting stock price data for WDC from 2000-01-01 to 2024-03-03
# 2024-03-03 20:49:14,432, data_manager.py, 115, INFO, Getting stock price data for WDC from 2000-01-01 to 2024-03-03
# [*********************100%%**********************]  1 of 1 completed
# 2024-03-03 20:49:14,934, data_manager.py, 89, INFO, Saving data for WDC by year
# 2024-03-03 20:49:14,934, data_manager.py, 89, INFO, Saving data for WDC by year
# 2024-03-03 20:49:16,069, data_manager.py, 80, INFO, Processing ticker WRK
# 2024-03-03 20:49:16,069, data_manager.py, 80, INFO, Processing ticker WRK
# 2024-03-03 20:49:16,069, data_manager.py, 115, INFO, Getting stock price data for WRK from 2000-01-01 to 2024-03-03
# 2024-03-03 20:49:16,069, data_manager.py, 115, INFO, Getting stock price data for WRK from 2000-01-01 to 2024-03-03
# [*********************100%%**********************]  1 of 1 completed
# 2024-03-03 20:49:16,302, data_manager.py, 89, INFO, Saving data for WRK by year
# 2024-03-03 20:49:16,302, data_manager.py, 89, INFO, Saving data for WRK by year
# 2024-03-03 20:49:16,738, data_manager.py, 80, INFO, Processing ticker WY
# 2024-03-03 20:49:16,738, data_manager.py, 80, INFO, Processing ticker WY
# 2024-03-03 20:49:16,740, data_manager.py, 115, INFO, Getting stock price data for WY from 2000-01-01 to 2024-03-03
# 2024-03-03 20:49:16,740, data_manager.py, 115, INFO, Getting stock price data for WY from 2000-01-01 to 2024-03-03
# [*********************100%%**********************]  1 of 1 completed
# 2024-03-03 20:49:17,200, data_manager.py, 89, INFO, Saving data for WY by year
# 2024-03-03 20:49:17,200, data_manager.py, 89, INFO, Saving data for WY by year
# 2024-03-03 20:49:18,301, data_manager.py, 80, INFO, Processing ticker WHR
# 2024-03-03 20:49:18,301, data_manager.py, 80, INFO, Processing ticker WHR
# 2024-03-03 20:49:18,301, data_manager.py, 115, INFO, Getting stock price data for WHR from 2000-01-01 to 2024-03-03
# 2024-03-03 20:49:18,301, data_manager.py, 115, INFO, Getting stock price data for WHR from 2000-01-01 to 2024-03-03
# [*********************100%%**********************]  1 of 1 completed
# 2024-03-03 20:49:18,738, data_manager.py, 89, INFO, Saving data for WHR by year
# 2024-03-03 20:49:18,738, data_manager.py, 89, INFO, Saving data for WHR by year
# 2024-03-03 20:49:19,871, data_manager.py, 80, INFO, Processing ticker WMB
# 2024-03-03 20:49:19,871, data_manager.py, 80, INFO, Processing ticker WMB
# 2024-03-03 20:49:19,874, data_manager.py, 115, INFO, Getting stock price data for WMB from 2000-01-01 to 2024-03-03
# 2024-03-03 20:49:19,874, data_manager.py, 115, INFO, Getting stock price data for WMB from 2000-01-01 to 2024-03-03
# [*********************100%%**********************]  1 of 1 completed
# 2024-03-03 20:49:23,826, data_manager.py, 89, INFO, Saving data for WMB by year
# 2024-03-03 20:49:23,826, data_manager.py, 89, INFO, Saving data for WMB by year
# 2024-03-03 20:49:24,774, data_manager.py, 80, INFO, Processing ticker WTW
# 2024-03-03 20:49:24,774, data_manager.py, 80, INFO, Processing ticker WTW
# 2024-03-03 20:49:24,774, data_manager.py, 115, INFO, Getting stock price data for WTW from 2000-01-01 to 2024-03-03
# 2024-03-03 20:49:24,774, data_manager.py, 115, INFO, Getting stock price data for WTW from 2000-01-01 to 2024-03-03
# [*********************100%%**********************]  1 of 1 completed
# 2024-03-03 20:49:25,445, data_manager.py, 89, INFO, Saving data for WTW by year
# 2024-03-03 20:49:25,445, data_manager.py, 89, INFO, Saving data for WTW by year
# 2024-03-03 20:49:26,392, data_manager.py, 80, INFO, Processing ticker GWW
# 2024-03-03 20:49:26,392, data_manager.py, 80, INFO, Processing ticker GWW
# 2024-03-03 20:49:26,392, data_manager.py, 115, INFO, Getting stock price data for GWW from 2000-01-01 to 2024-03-03
# 2024-03-03 20:49:26,392, data_manager.py, 115, INFO, Getting stock price data for GWW from 2000-01-01 to 2024-03-03
# [*********************100%%**********************]  1 of 1 completed
# 2024-03-03 20:49:26,826, data_manager.py, 89, INFO, Saving data for GWW by year
# 2024-03-03 20:49:26,826, data_manager.py, 89, INFO, Saving data for GWW by year
# 2024-03-03 20:49:30,136, data_manager.py, 80, INFO, Processing ticker WYNN
# 2024-03-03 20:49:30,136, data_manager.py, 80, INFO, Processing ticker WYNN
# 2024-03-03 20:49:30,136, data_manager.py, 115, INFO, Getting stock price data for WYNN from 2000-01-01 to 2024-03-03
# 2024-03-03 20:49:30,136, data_manager.py, 115, INFO, Getting stock price data for WYNN from 2000-01-01 to 2024-03-03
# [*********************100%%**********************]  1 of 1 completed
# 2024-03-03 20:49:30,513, data_manager.py, 89, INFO, Saving data for WYNN by year
# 2024-03-03 20:49:30,513, data_manager.py, 89, INFO, Saving data for WYNN by year
# 2024-03-03 20:49:31,576, data_manager.py, 80, INFO, Processing ticker XEL
# 2024-03-03 20:49:31,576, data_manager.py, 80, INFO, Processing ticker XEL
# 2024-03-03 20:49:31,578, data_manager.py, 115, INFO, Getting stock price data for XEL from 2000-01-01 to 2024-03-03
# 2024-03-03 20:49:31,578, data_manager.py, 115, INFO, Getting stock price data for XEL from 2000-01-01 to 2024-03-03
# [*********************100%%**********************]  1 of 1 completed
# 2024-03-03 20:49:32,280, data_manager.py, 89, INFO, Saving data for XEL by year
# 2024-03-03 20:49:32,280, data_manager.py, 89, INFO, Saving data for XEL by year
# 2024-03-03 20:49:33,312, data_manager.py, 80, INFO, Processing ticker XYL
# 2024-03-03 20:49:33,312, data_manager.py, 80, INFO, Processing ticker XYL
# 2024-03-03 20:49:33,312, data_manager.py, 115, INFO, Getting stock price data for XYL from 2000-01-01 to 2024-03-03
# 2024-03-03 20:49:33,312, data_manager.py, 115, INFO, Getting stock price data for XYL from 2000-01-01 to 2024-03-03
# [*********************100%%**********************]  1 of 1 completed
# 2024-03-03 20:49:33,810, data_manager.py, 89, INFO, Saving data for XYL by year
# 2024-03-03 20:49:33,810, data_manager.py, 89, INFO, Saving data for XYL by year
# 2024-03-03 20:49:34,381, data_manager.py, 80, INFO, Processing ticker YUM
# 2024-03-03 20:49:34,381, data_manager.py, 80, INFO, Processing ticker YUM
# 2024-03-03 20:49:34,381, data_manager.py, 115, INFO, Getting stock price data for YUM from 2000-01-01 to 2024-03-03
# 2024-03-03 20:49:34,381, data_manager.py, 115, INFO, Getting stock price data for YUM from 2000-01-01 to 2024-03-03
# [*********************100%%**********************]  1 of 1 completed
# 2024-03-03 20:49:34,871, data_manager.py, 89, INFO, Saving data for YUM by year
# 2024-03-03 20:49:34,871, data_manager.py, 89, INFO, Saving data for YUM by year
# 2024-03-03 20:49:35,867, data_manager.py, 80, INFO, Processing ticker ZBRA
# 2024-03-03 20:49:35,867, data_manager.py, 80, INFO, Processing ticker ZBRA
# 2024-03-03 20:49:35,867, data_manager.py, 115, INFO, Getting stock price data for ZBRA from 2000-01-01 to 2024-03-03
# 2024-03-03 20:49:35,867, data_manager.py, 115, INFO, Getting stock price data for ZBRA from 2000-01-01 to 2024-03-03
# [*********************100%%**********************]  1 of 1 completed
# 2024-03-03 20:49:36,180, data_manager.py, 89, INFO, Saving data for ZBRA by year
# 2024-03-03 20:49:36,180, data_manager.py, 89, INFO, Saving data for ZBRA by year
# 2024-03-03 20:49:37,300, data_manager.py, 80, INFO, Processing ticker ZBH
# 2024-03-03 20:49:37,300, data_manager.py, 80, INFO, Processing ticker ZBH
# 2024-03-03 20:49:37,316, data_manager.py, 115, INFO, Getting stock price data for ZBH from 2000-01-01 to 2024-03-03
# 2024-03-03 20:49:37,316, data_manager.py, 115, INFO, Getting stock price data for ZBH from 2000-01-01 to 2024-03-03
# [*********************100%%**********************]  1 of 1 completed
# 2024-03-03 20:49:37,640, data_manager.py, 89, INFO, Saving data for ZBH by year
# 2024-03-03 20:49:37,640, data_manager.py, 89, INFO, Saving data for ZBH by year
# 2024-03-03 20:49:38,604, data_manager.py, 80, INFO, Processing ticker ZION
# 2024-03-03 20:49:38,604, data_manager.py, 80, INFO, Processing ticker ZION
# 2024-03-03 20:49:38,621, data_manager.py, 115, INFO, Getting stock price data for ZION from 2000-01-01 to 2024-03-03
# 2024-03-03 20:49:38,621, data_manager.py, 115, INFO, Getting stock price data for ZION from 2000-01-01 to 2024-03-03
# [*********************100%%**********************]  1 of 1 completed
# 2024-03-03 20:49:39,029, data_manager.py, 89, INFO, Saving data for ZION by year
# 2024-03-03 20:49:39,029, data_manager.py, 89, INFO, Saving data for ZION by year

# %%
dm.featurize()
